# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime 
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
Number_of_cities = len(cities)
Number_of_cities
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#City	Lat	Lng	Max Temp	Humidity	Cloudiness	Wind Speed	Country	Date
#city_results = []
#Index_cities=[]

City_Number = []
City_Name = []
City_Lat = []
City_Lng = []
City_MaxTemp = []
City_Humidity = []
City_Cloudiness = []
City_WindSpeed = []
City_Country = []
City_Date = []
Count_Record = 0
  
#city_ejempo=['London','Melbourne','Alaska','Jazan','Caracas','Harare','El Junquito','New Orleans',"GTY77","Maracay","Washington", "Pensilvanya", "Palita", "guarenas", "Atlanta", "Bogota"]

for city in cities:    # cities[:100]: to just do it for 100 rows (City) test
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial"
    #print(url) 
    Req_weather_city = requests.get(url).json()
    if (Req_weather_city["cod"]==200):
        Count_Record = Count_Record + 1
        City_Number.append(Req_weather_city['id'])
        City_Name.append(Req_weather_city['name'])
        City_Lat.append(Req_weather_city['coord']['lat'])
        City_Lng.append(Req_weather_city['coord']['lon'])
        City_MaxTemp.append(Req_weather_city['main']['temp'])
        City_Humidity.append(Req_weather_city['main']['humidity'])
        City_Cloudiness.append(Req_weather_city['clouds']['all'])
        City_WindSpeed.append(Req_weather_city['wind']['speed'])
        City_Country.append(Req_weather_city['sys']['country'])
        City_Date.append(Req_weather_city['dt'])
        print(f"Processing Record {Count_Record} of {Number_of_cities} |City number: {Req_weather_city['id']}, City name: {Req_weather_city['name']}")
    else: 
        #{"cod":"404","message":"city not found"}
        print(f"{city}: {Req_weather_city['message']}. Skipping...")

weather_dict = {
    "City": City_Name,
    "Lat": City_Lat,
    "Lng":City_Lng,
    "Temp": City_MaxTemp,
    "Humidity":City_Humidity,
    "Cloudiness":City_Cloudiness,
    "Wind Speed":City_WindSpeed,
    "Country":City_Country,
    "Date":City_Date 
}
meteorology_cities = pd.DataFrame(weather_dict)
# Out:
# Processing Record 1 of 632 |City number: 3466980, City name: Caravelas
# ust-kamchatsk: city not found. Skipping...
# Processing Record 2 of 632 |City number: 5972762, City name: Hay River
# Processing Record 3 of 632 |City number: 3430863, City name: Mar del Plata
# Processing Record 4 of 632 |City number: 2427336, City name: Moussoro
# belushya guba: city not found. Skipping...
# Processing Record 5 of 632 |City number: 546105, City name: Nikolskoye
# Processing Record 6 of 632 |City number: 6201424, City name: Mataura
# Processing Record 7 of 632 |City number: 3471451, City name: Arraial do Cabo
# Processing Record 8 of 632 |City number: 6071618, City name: Medicine Hat
# Processing Record 9 of 632 |City number: 3366880, City name: Hermanus
# taolanaro: city not found. Skipping...
# Processing Record 10 of 632 |City number: 5282297, City name: Bethel
# Processing Record 11 of 632 |City number: 3418910, City name: Upernavik
# Processing Record 12 of 632 |City number: 3839307, City name: Rawson
# Processing Record 13 of 632 |City number: 2392087, City name: Porto-Novo
# Processing Record 14 of 632 |City number: 5122534, City name: Jamestown
# Processing Record 15 of 632 |City number: 5961417, City name: Gimli
# Processing Record 16 of 632 |City number: 1507390, City name: Dikson
# Processing Record 17 of 632 |City number: 582447, City name: Almaznyy
# illoqqortoormiut: city not found. Skipping...
# Processing Record 18 of 632 |City number: 2138555, City name: Poum
# Processing Record 19 of 632 |City number: 1006984, City name: East London
# Processing Record 20 of 632 |City number: 2075265, City name: Busselton
# Processing Record 21 of 632 |City number: 3883457, City name: Lebu
# Processing Record 22 of 632 |City number: 1528998, City name: Yumen
# Processing Record 23 of 632 |City number: 5880054, City name: Barrow
# Processing Record 24 of 632 |City number: 4560349, City name: Philadelphia
# Processing Record 25 of 632 |City number: 3924895, City name: Plácido de Castro
# Processing Record 26 of 632 |City number: 3369157, City name: Cape Town
# Processing Record 27 of 632 |City number: 4513583, City name: Hamilton
# Processing Record 28 of 632 |City number: 3833367, City name: Ushuaia
# Processing Record 29 of 632 |City number: 5307540, City name: Oro Valley
# Processing Record 30 of 632 |City number: 2128975, City name: Nemuro
# Processing Record 31 of 632 |City number: 5855927, City name: Hilo
# Processing Record 32 of 632 |City number: 2155415, City name: New Norfolk
# Processing Record 33 of 632 |City number: 1214073, City name: Rantauprapat
# Processing Record 34 of 632 |City number: 2686469, City name: Örnsköldsvik
# Processing Record 35 of 632 |City number: 933109, City name: Sehithwa
# Processing Record 36 of 632 |City number: 3831208, City name: Qaanaaq
# Processing Record 37 of 632 |City number: 6170031, City name: Tuktoyaktuk
# Processing Record 38 of 632 |City number: 6185377, City name: Yellowknife
# bacuit: city not found. Skipping...
# saleaula: city not found. Skipping...
# Processing Record 39 of 632 |City number: 4032243, City name: Vaini
# Processing Record 40 of 632 |City number: 934322, City name: Mahébourg
# Processing Record 41 of 632 |City number: 5380437, City name: Pacific Grove
# Processing Record 42 of 632 |City number: 1632694, City name: Pangkalanbuun
# Processing Record 43 of 632 |City number: 4944903, City name: Nantucket
# Processing Record 44 of 632 |City number: 3126369, City name: Carballo
# Processing Record 45 of 632 |City number: 1649150, City name: Bengkulu
# Processing Record 46 of 632 |City number: 2243271, City name: Cabinda
# Processing Record 47 of 632 |City number: 5106841, City name: Albany
# Processing Record 48 of 632 |City number: 2738381, City name: Lata
# Processing Record 49 of 632 |City number: 3838859, City name: Río Gallegos
# Processing Record 50 of 632 |City number: 2729907, City name: Longyearbyen
# Processing Record 51 of 632 |City number: 5367788, City name: Lompoc
# Processing Record 52 of 632 |City number: 4034551, City name: Faanui
# Processing Record 53 of 632 |City number: 3874787, City name: Punta Arenas
# Processing Record 54 of 632 |City number: 229599, City name: Lyantonde
# Processing Record 55 of 632 |City number: 1634614, City name: Nabire
# Processing Record 56 of 632 |City number: 187968, City name: Malindi
# Processing Record 57 of 632 |City number: 2074865, City name: Carnarvon
# Processing Record 58 of 632 |City number: 3530110, City name: Coyutla
# Processing Record 59 of 632 |City number: 2206939, City name: Bluff
# Processing Record 60 of 632 |City number: 2110227, City name: Butaritari
# Processing Record 61 of 632 |City number: 2155562, City name: Nelson Bay
# Processing Record 62 of 632 |City number: 3899695, City name: Ancud
# Processing Record 63 of 632 |City number: 1168312, City name: Pasni
# Processing Record 64 of 632 |City number: 2264557, City name: Ponta do Sol
# Processing Record 65 of 632 |City number: 777019, City name: Vardø
# barentsburg: city not found. Skipping...
# Processing Record 66 of 632 |City number: 2392204, City name: Parakou
# Processing Record 67 of 632 |City number: 2122090, City name: Pevek
# Processing Record 68 of 632 |City number: 6165406, City name: Thompson
# Processing Record 69 of 632 |City number: 2123814, City name: Leningradskiy
# Processing Record 70 of 632 |City number: 2449893, City name: Tessalit
# Processing Record 71 of 632 |City number: 4030556, City name: Rikitea
# Processing Record 72 of 632 |City number: 2022572, City name: Khatanga
# Processing Record 73 of 632 |City number: 3461013, City name: Irecê
# Processing Record 74 of 632 |City number: 2163355, City name: Hobart
# Processing Record 75 of 632 |City number: 5866583, City name: Saint Paul Harbor
# Processing Record 76 of 632 |City number: 4036284, City name: Alofi
# Processing Record 77 of 632 |City number: 686090, City name: Asău
# Processing Record 78 of 632 |City number: 964432, City name: Port Alfred
# Processing Record 79 of 632 |City number: 3374210, City name: São Filipe
# Processing Record 80 of 632 |City number: 1180729, City name: Dalbandin
# Processing Record 81 of 632 |City number: 3115824, City name: Muros
# paradwip: city not found. Skipping...
# tsihombe: city not found. Skipping...
# Processing Record 82 of 632 |City number: 4020109, City name: Atuona
# Processing Record 83 of 632 |City number: 3887344, City name: Illapel
# Processing Record 84 of 632 |City number: 3175096, City name: Laas
# Processing Record 85 of 632 |City number: 3870243, City name: Taltal
# Processing Record 86 of 632 |City number: 2112309, City name: Katsuura
# Processing Record 87 of 632 |City number: 2439155, City name: Tanout
# toungoo: city not found. Skipping...
# Processing Record 88 of 632 |City number: 1802068, City name: Lujiang
# Processing Record 89 of 632 |City number: 2509377, City name: Zafra
# Processing Record 90 of 632 |City number: 1015776, City name: Bredasdorp
# Processing Record 91 of 632 |City number: 3573374, City name: The Valley
# Processing Record 92 of 632 |City number: 1640344, City name: Kendari
# Processing Record 93 of 632 |City number: 3424607, City name: Tasiilaq
# Processing Record 94 of 632 |City number: 3430443, City name: Necochea
# Processing Record 95 of 632 |City number: 1045114, City name: Inhambane
# Processing Record 96 of 632 |City number: 1106677, City name: Bambous Virieux
# Processing Record 97 of 632 |City number: 2180815, City name: Tuatapere
# Processing Record 98 of 632 |City number: 4740364, City name: Weatherford
# Processing Record 99 of 632 |City number: 2021017, City name: Kysyl-Syr
# Processing Record 100 of 632 |City number: 5546220, City name: Saint George
# Processing Record 101 of 632 |City number: 2151437, City name: Rockhampton
# Processing Record 102 of 632 |City number: 2374583, City name: Bubaque
# Processing Record 103 of 632 |City number: 293842, City name: Kiryat Gat
# Processing Record 104 of 632 |City number: 933995, City name: Souillac
# Processing Record 105 of 632 |City number: 3105522, City name: Bereda
# Processing Record 106 of 632 |City number: 3681505, City name: Guapí
# Processing Record 107 of 632 |City number: 1651810, City name: Airai
# Processing Record 108 of 632 |City number: 2126123, City name: Chokurdakh
# Processing Record 109 of 632 |City number: 3652764, City name: Puerto Ayora
# Processing Record 110 of 632 |City number: 2332459, City name: Ijero
# Processing Record 111 of 632 |City number: 5847411, City name: Kahului
# Processing Record 112 of 632 |City number: 3860443, City name: Comodoro Rivadavia
# Processing Record 113 of 632 |City number: 5861897, City name: Fairbanks
# Processing Record 114 of 632 |City number: 2121385, City name: Severo-Kuril'sk
# Processing Record 115 of 632 |City number: 1282256, City name: Hithadhoo
# Processing Record 116 of 632 |City number: 2521582, City name: Arona
# Processing Record 117 of 632 |City number: 5848280, City name: Kapaa
# Processing Record 118 of 632 |City number: 935215, City name: Saint-Philippe
# Processing Record 119 of 632 |City number: 3359736, City name: Vredendal
# Processing Record 120 of 632 |City number: 3625710, City name: Upata
# Processing Record 121 of 632 |City number: 4021858, City name: Guerrero Negro
# Processing Record 122 of 632 |City number: 1798760, City name: Pingliang
# Processing Record 123 of 632 |City number: 2194098, City name: Ahipara
# Processing Record 124 of 632 |City number: 3355672, City name: Lüderitz
# Processing Record 125 of 632 |City number: 1267390, City name: Kavaratti
# Processing Record 126 of 632 |City number: 3372707, City name: Ribeira Grande
# Processing Record 127 of 632 |City number: 3443061, City name: Chui
# Processing Record 128 of 632 |City number: 3414079, City name: Olafsvik
# haibowan: city not found. Skipping...
# Processing Record 129 of 632 |City number: 2015306, City name: Tiksi
# kegayli: city not found. Skipping...
# Processing Record 130 of 632 |City number: 4033077, City name: Vaitape
# Processing Record 131 of 632 |City number: 3988392, City name: Rosarito
# Processing Record 132 of 632 |City number: 6180550, City name: Whitehorse
# Processing Record 133 of 632 |City number: 245785, City name: Abéché
# Processing Record 134 of 632 |City number: 2377450, City name: Nouakchott
# Processing Record 135 of 632 |City number: 2013279, City name: Vostok
# Processing Record 136 of 632 |City number: 3423146, City name: Ilulissat
# longlac: city not found. Skipping...
# Processing Record 137 of 632 |City number: 3939761, City name: Hualmay
# Processing Record 138 of 632 |City number: 2022064, City name: Kirovskiy
# Processing Record 139 of 632 |City number: 3466704, City name: Castro
# Processing Record 140 of 632 |City number: 1510377, City name: Belyy Yar
# Processing Record 141 of 632 |City number: 1544583, City name: Uyskoye
# Processing Record 142 of 632 |City number: 7601762, City name: Bairiki Village
# Processing Record 143 of 632 |City number: 2619537, City name: Hvide Sande
# Processing Record 144 of 632 |City number: 175499, City name: Nchelenge
# ambodifototra: city not found. Skipping...
# Processing Record 145 of 632 |City number: 4362001, City name: Mayo
# saryshagan: city not found. Skipping...
# Processing Record 146 of 632 |City number: 3657661, City name: Gualaquiza
# Processing Record 147 of 632 |City number: 2017155, City name: Saskylakh
# Processing Record 148 of 632 |City number: 2191562, City name: Dunedin
# Processing Record 149 of 632 |City number: 6089245, City name: Norman Wells
# mys shmidta: city not found. Skipping...
# Processing Record 150 of 632 |City number: 159134, City name: Inyonga
# Processing Record 151 of 632 |City number: 570813, City name: Buribay
# Processing Record 152 of 632 |City number: 2090021, City name: Namatanai
# Processing Record 153 of 632 |City number: 525426, City name: Monastyrshchina
# Processing Record 154 of 632 |City number: 556268, City name: Ostrovnoy
# Processing Record 155 of 632 |City number: 4035715, City name: Avarua
# Processing Record 156 of 632 |City number: 2112802, City name: Hasaki
# Processing Record 157 of 632 |City number: 2016216, City name: Sosnovo-Ozerskoye
# Processing Record 158 of 632 |City number: 2126710, City name: Beringovskiy
# Processing Record 159 of 632 |City number: 5924351, City name: Clyde River
# Processing Record 160 of 632 |City number: 1819729, City name: Hong Kong
# Processing Record 161 of 632 |City number: 338345, City name: Edd
# Processing Record 162 of 632 |City number: 178077, City name: Wote
# dolbeau: city not found. Skipping...
# Processing Record 163 of 632 |City number: 935616, City name: Le Port
# Processing Record 164 of 632 |City number: 1855540, City name: Naze
# Processing Record 165 of 632 |City number: 553766, City name: Kamenka
# Processing Record 166 of 632 |City number: 1055059, City name: Tsaratanana
# Processing Record 167 of 632 |City number: 1498087, City name: Nadym
# Processing Record 168 of 632 |City number: 2129868, City name: Iwanai
# Processing Record 169 of 632 |City number: 1267433, City name: Kattivākkam
# Processing Record 170 of 632 |City number: 337405, City name: Gambēla
# Processing Record 171 of 632 |City number: 5557293, City name: Sitka
# Processing Record 172 of 632 |City number: 3440777, City name: Rocha
# Processing Record 173 of 632 |City number: 2156643, City name: Mount Gambier
# Processing Record 174 of 632 |City number: 2562619, City name: Saint Lawrence
# Processing Record 175 of 632 |City number: 287286, City name: Ruwi
# Processing Record 176 of 632 |City number: 934649, City name: Cap Malheureux
# Processing Record 177 of 632 |City number: 113508, City name: Takāb
# Processing Record 178 of 632 |City number: 3628473, City name: San Cristobal
# Processing Record 179 of 632 |City number: 779554, City name: Honningsvåg
# Processing Record 180 of 632 |City number: 4031574, City name: Provideniya
# Processing Record 181 of 632 |City number: 64814, City name: Bandarbeyla
# Processing Record 182 of 632 |City number: 286621, City name: Salalah
# Processing Record 183 of 632 |City number: 1496503, City name: Noyabrsk
# Processing Record 184 of 632 |City number: 5919850, City name: Chapais
# Processing Record 185 of 632 |City number: 2641598, City name: Newport
# Processing Record 186 of 632 |City number: 364933, City name: Umm Kaddadah
# Processing Record 187 of 632 |City number: 2630299, City name: Hofn
# Processing Record 188 of 632 |City number: 3522788, City name: Nautla
# Processing Record 189 of 632 |City number: 3395458, City name: Maragogi
# Processing Record 190 of 632 |City number: 3382226, City name: Camopi
# Processing Record 191 of 632 |City number: 515805, City name: Oktyabr'skoye
# Processing Record 192 of 632 |City number: 964712, City name: Plettenberg Bay
# Processing Record 193 of 632 |City number: 3361934, City name: Saldanha
# Processing Record 194 of 632 |City number: 1513491, City name: Yangi Marg`ilon
# Processing Record 195 of 632 |City number: 6323121, City name: Florianópolis
# Processing Record 196 of 632 |City number: 2057087, City name: Kupang
# Processing Record 197 of 632 |City number: 4033543, City name: Teahupoo
# Processing Record 198 of 632 |City number: 2206874, City name: Waipawa
# Processing Record 199 of 632 |City number: 3932145, City name: Pisco
# Processing Record 200 of 632 |City number: 2063042, City name: Port Hedland
# Processing Record 201 of 632 |City number: 2013258, City name: Vrangel'
# Processing Record 202 of 632 |City number: 2108502, City name: Honiara
# Processing Record 203 of 632 |City number: 2160735, City name: Lakes Entrance
# Processing Record 204 of 632 |City number: 4031637, City name: Lavrentiya
# Processing Record 205 of 632 |City number: 3836277, City name: Santa Fe
# Processing Record 206 of 632 |City number: 602150, City name: Umeå
# Processing Record 207 of 632 |City number: 4004293, City name: Ixtapa
# Processing Record 208 of 632 |City number: 3689458, City name: Astrea
# Processing Record 209 of 632 |City number: 1498283, City name: Mugur-Aksy
# Processing Record 210 of 632 |City number: 1788852, City name: Xining
# toliary: city not found. Skipping...
# Processing Record 211 of 632 |City number: 3466165, City name: Cidreira
# Processing Record 212 of 632 |City number: 1650232, City name: Banjar
# Processing Record 213 of 632 |City number: 2315026, City name: Kasongo-Lunda
# marcona: city not found. Skipping...
# Processing Record 214 of 632 |City number: 527321, City name: Mezen'
# macaboboni: city not found. Skipping...
# Processing Record 215 of 632 |City number: 2027316, City name: Ayan
# Processing Record 216 of 632 |City number: 3420846, City name: Qaqortoq
# Processing Record 217 of 632 |City number: 541256, City name: Krechevitsy
# Processing Record 218 of 632 |City number: 3537840, City name: Santa Cruz del Sur
# Processing Record 219 of 632 |City number: 3421719, City name: Narsaq
# Processing Record 220 of 632 |City number: 189280, City name: Lodwar
# Processing Record 221 of 632 |City number: 3374083, City name: Bathsheba
# Processing Record 222 of 632 |City number: 542184, City name: Krasnovishersk
# Processing Record 223 of 632 |City number: 3452327, City name: Presidente Olegário
# Processing Record 224 of 632 |City number: 2014624, City name: Udachny
# Processing Record 225 of 632 |City number: 3899539, City name: Antofagasta
# Processing Record 226 of 632 |City number: 773357, City name: Dęblin
# Processing Record 227 of 632 |City number: 2145554, City name: Ulladulla
# Processing Record 228 of 632 |City number: 3381041, City name: Mana
# Processing Record 229 of 632 |City number: 327651, City name: Teseney
# Processing Record 230 of 632 |City number: 3381538, City name: Grand-Santi
# amderma: city not found. Skipping...
# Processing Record 231 of 632 |City number: 2171099, City name: Codrington
# Processing Record 232 of 632 |City number: 3984997, City name: San Quintín
# Processing Record 233 of 632 |City number: 290030, City name: Doha
# Processing Record 234 of 632 |City number: 5110365, City name: Broome
# taburi: city not found. Skipping...
# Processing Record 235 of 632 |City number: 1215502, City name: Banda Aceh
# Processing Record 236 of 632 |City number: 2126682, City name: Bilibino
# Processing Record 237 of 632 |City number: 2093685, City name: Kokopo
# Processing Record 238 of 632 |City number: 333795, City name: Jijiga
# Processing Record 239 of 632 |City number: 6141256, City name: Saskatoon
# Processing Record 240 of 632 |City number: 2070998, City name: Geraldton
# Processing Record 241 of 632 |City number: 964420, City name: Port Elizabeth
# Processing Record 242 of 632 |City number: 5814916, City name: Walla Walla
# Processing Record 243 of 632 |City number: 72181, City name: Marzuq
# Processing Record 244 of 632 |City number: 2629833, City name: Husavik
# Processing Record 245 of 632 |City number: 990930, City name: Kimberley
# Processing Record 246 of 632 |City number: 4764534, City name: Hollins
# Processing Record 247 of 632 |City number: 2136825, City name: Isangel
# Processing Record 248 of 632 |City number: 1271113, City name: Godda
# Processing Record 249 of 632 |City number: 962367, City name: Richards Bay
# Processing Record 250 of 632 |City number: 2071860, City name: Esperance
# Processing Record 251 of 632 |City number: 3347019, City name: Mossamedes
# bur gabo: city not found. Skipping...
# Processing Record 252 of 632 |City number: 1788508, City name: Xinyu
# Processing Record 253 of 632 |City number: 3421765, City name: Nanortalik
# Processing Record 254 of 632 |City number: 2209055, City name: Waddān
# Processing Record 255 of 632 |City number: 5849996, City name: Lahaina
# Processing Record 256 of 632 |City number: 1496511, City name: Novy Urengoy
# Processing Record 257 of 632 |City number: 3664980, City name: Boa Vista
# Processing Record 258 of 632 |City number: 2094342, City name: Kavieng
# Processing Record 259 of 632 |City number: 5301388, City name: Lake Havasu City
# Processing Record 260 of 632 |City number: 3374235, City name: Sal Rei
# Processing Record 261 of 632 |City number: 7671223, City name: Kloulklubed
# Processing Record 262 of 632 |City number: 2618795, City name: Klaksvík
# Processing Record 263 of 632 |City number: 6113406, City name: Prince Rupert
# Processing Record 264 of 632 |City number: 215605, City name: Kabare
# Processing Record 265 of 632 |City number: 374739, City name: Gogrial
# Processing Record 266 of 632 |City number: 2409914, City name: Bonthe
# Processing Record 267 of 632 |City number: 707296, City name: Izyaslav
# yithion: city not found. Skipping...
# Processing Record 268 of 632 |City number: 5955902, City name: Fort Nelson
# Processing Record 269 of 632 |City number: 1218436, City name: Saýat
# grand river south east: city not found. Skipping...
# Processing Record 270 of 632 |City number: 4355274, City name: Forestville
# Processing Record 271 of 632 |City number: 921906, City name: Domoni
# Processing Record 272 of 632 |City number: 1260138, City name: Pathanāmthitta
# Processing Record 273 of 632 |City number: 2026861, City name: Berdigestyakh
# Processing Record 274 of 632 |City number: 2360372, City name: Gorom-Gorom
# Processing Record 275 of 632 |City number: 1489853, City name: Tazovsky
# Processing Record 276 of 632 |City number: 1213821, City name: Sigli
# Processing Record 277 of 632 |City number: 6096551, City name: Pangnirtung
# Processing Record 278 of 632 |City number: 1224061, City name: Wattegama
# Processing Record 279 of 632 |City number: 1489822, City name: Tegul'det
# Processing Record 280 of 632 |City number: 1793511, City name: Taiyuan
# Processing Record 281 of 632 |City number: 2129513, City name: Shimokizukuri
# Processing Record 282 of 632 |City number: 3372964, City name: Lagoa
# Processing Record 283 of 632 |City number: 200308, City name: Sotik Post
# Processing Record 284 of 632 |City number: 1684245, City name: Tagusao
# halalo: city not found. Skipping...
# Processing Record 285 of 632 |City number: 4004867, City name: Parral
# Processing Record 286 of 632 |City number: 3407903, City name: Almeirim
# Processing Record 287 of 632 |City number: 4034307, City name: Mahina
# Processing Record 288 of 632 |City number: 4993659, City name: Garden City
# Processing Record 289 of 632 |City number: 1835848, City name: Seoul
# Processing Record 290 of 632 |City number: 6137462, City name: Saint-Augustin
# Processing Record 291 of 632 |City number: 2126199, City name: Cherskiy
# Processing Record 292 of 632 |City number: 3174050, City name: Province of Mantua
# Processing Record 293 of 632 |City number: 1162105, City name: Zhob
# Processing Record 294 of 632 |City number: 6144054, City name: Selkirk
# Processing Record 295 of 632 |City number: 53372, City name: Oodweyne
# Processing Record 296 of 632 |City number: 5597955, City name: Kuna
# Processing Record 297 of 632 |City number: 1502073, City name: Krasnosel'kup
# Processing Record 298 of 632 |City number: 3470137, City name: Belmonte
# Processing Record 299 of 632 |City number: 5357155, City name: Hillsborough
# Processing Record 300 of 632 |City number: 3421319, City name: Nuuk
# Processing Record 301 of 632 |City number: 53157, City name: Qandala
# Processing Record 302 of 632 |City number: 2654970, City name: Brae
# Processing Record 303 of 632 |City number: 1735106, City name: George Town
# Processing Record 304 of 632 |City number: 2522875, City name: Province of Trapani
# Processing Record 305 of 632 |City number: 3405215, City name: Bonfim
# Processing Record 306 of 632 |City number: 4013679, City name: Coahuayana Viejo
# Processing Record 307 of 632 |City number: 895953, City name: Zambezi
# el faiyum: city not found. Skipping...
# Processing Record 308 of 632 |City number: 3353383, City name: Rundu
# Processing Record 309 of 632 |City number: 3492985, City name: Santa Cruz de Barahona
# Processing Record 310 of 632 |City number: 257122, City name: Methóni
# Processing Record 311 of 632 |City number: 5969025, City name: Haines Junction
# Processing Record 312 of 632 |City number: 1490256, City name: Talnakh
# Processing Record 313 of 632 |City number: 1862505, City name: Hirara
# Processing Record 314 of 632 |City number: 4120388, City name: Malvern
# Processing Record 315 of 632 |City number: 1715015, City name: Dicabisagan
# Processing Record 316 of 632 |City number: 6255012, City name: Flinders
# Processing Record 317 of 632 |City number: 1486321, City name: Yar-Sale
# Processing Record 318 of 632 |City number: 2610343, City name: Vestmanna
# Processing Record 319 of 632 |City number: 1701054, City name: Marawi
# Processing Record 320 of 632 |City number: 3404231, City name: Caetés
# Processing Record 321 of 632 |City number: 6355222, City name: Yulara
# Processing Record 322 of 632 |City number: 2152659, City name: Port Macquarie
# Processing Record 323 of 632 |City number: 2301217, City name: Ejura
# Processing Record 324 of 632 |City number: 466060, City name: Yuzhno-Sukhokumsk
# tabiauea: city not found. Skipping...
# Processing Record 325 of 632 |City number: 478317, City name: Usman'
# Processing Record 326 of 632 |City number: 4946620, City name: Palmer
# Processing Record 327 of 632 |City number: 3386213, City name: Touros
# Processing Record 328 of 632 |City number: 1637001, City name: Biak
# Processing Record 329 of 632 |City number: 1489246, City name: Troitsk
# kosgi: city not found. Skipping...
# Processing Record 330 of 632 |City number: 3571913, City name: Marsh Harbour
# Processing Record 331 of 632 |City number: 3442727, City name: Durazno
# Processing Record 332 of 632 |City number: 1737185, City name: Kapit
# Processing Record 333 of 632 |City number: 3407882, City name: Altamira
# Processing Record 334 of 632 |City number: 2083537, City name: Wewak
# Processing Record 335 of 632 |City number: 3622716, City name: Nicoya
# Processing Record 336 of 632 |City number: 2370473, City name: Quebo
# Processing Record 337 of 632 |City number: 2210554, City name: Sirte
# Processing Record 338 of 632 |City number: 3412093, City name: Vestmannaeyjar
# attawapiskat: city not found. Skipping...
# palabuhanratu: city not found. Skipping...
# Processing Record 339 of 632 |City number: 5563839, City name: Fortuna
# Processing Record 340 of 632 |City number: 1622318, City name: Waingapu
# Processing Record 341 of 632 |City number: 2082539, City name: Merauke
# Processing Record 342 of 632 |City number: 884814, City name: Mvuma
# Processing Record 343 of 632 |City number: 2068110, City name: Kununurra
# Processing Record 344 of 632 |City number: 1636806, City name: Majene
# Processing Record 345 of 632 |City number: 2383523, City name: Paoua
# Processing Record 346 of 632 |City number: 5983720, City name: Iqaluit
# Processing Record 347 of 632 |City number: 1529484, City name: Kumul
# Processing Record 348 of 632 |City number: 1732826, City name: Mersing
# Processing Record 349 of 632 |City number: 2123621, City name: Mago
# Processing Record 350 of 632 |City number: 540761, City name: Kropotkin
# Processing Record 351 of 632 |City number: 2012530, City name: Zhigansk
# Processing Record 352 of 632 |City number: 3546791, City name: Moa
# Processing Record 353 of 632 |City number: 3421982, City name: Maniitsoq
# Processing Record 354 of 632 |City number: 3893629, City name: Coquimbo
# Processing Record 355 of 632 |City number: 1242110, City name: Kalmunai
# Processing Record 356 of 632 |City number: 1269507, City name: Jaisalmer
# sentyabrskiy: city not found. Skipping...
# Processing Record 357 of 632 |City number: 3361142, City name: Springbok
# Processing Record 358 of 632 |City number: 1706781, City name: Lianga
# Processing Record 359 of 632 |City number: 3170692, City name: Pineto
# Processing Record 360 of 632 |City number: 4657077, City name: Shelbyville
# Processing Record 361 of 632 |City number: 1854774, City name: Ōdachō-ōda
# Processing Record 362 of 632 |City number: 215976, City name: Ilebo
# Processing Record 363 of 632 |City number: 225835, City name: Yumbe
# Processing Record 364 of 632 |City number: 2015179, City name: Tommot
# Processing Record 365 of 632 |City number: 682873, City name: Calvini
# Processing Record 366 of 632 |City number: 6167817, City name: Torbay
# Processing Record 367 of 632 |City number: 3874930, City name: Puerto Varas
# Processing Record 368 of 632 |City number: 3939168, City name: Huarmey
# Processing Record 369 of 632 |City number: 2122574, City name: Ola
# Processing Record 370 of 632 |City number: 4726521, City name: San Patricio
# Processing Record 371 of 632 |City number: 2015686, City name: Talakan
# Processing Record 372 of 632 |City number: 3382160, City name: Cayenne
# Processing Record 373 of 632 |City number: 566629, City name: Demyansk
# Processing Record 374 of 632 |City number: 2381972, City name: Adrar
# armacao dos buzios: city not found. Skipping...
# Processing Record 375 of 632 |City number: 5983607, City name: Inuvik
# Processing Record 376 of 632 |City number: 2455290, City name: Kidal
# Processing Record 377 of 632 |City number: 1692364, City name: Puro
# Processing Record 378 of 632 |City number: 2120591, City name: Tilichiki
# Processing Record 379 of 632 |City number: 2178753, City name: Kirakira
# Processing Record 380 of 632 |City number: 1259385, City name: Port Blair
# Processing Record 381 of 632 |City number: 3393692, City name: Itarema
# Processing Record 382 of 632 |City number: 1261853, City name: Narasannapeta
# Processing Record 383 of 632 |City number: 1278827, City name: Ambikāpur
# Processing Record 384 of 632 |City number: 934479, City name: Grand Gaube
# Processing Record 385 of 632 |City number: 4166673, City name: Ocala
# Processing Record 386 of 632 |City number: 162199, City name: Annau
# Processing Record 387 of 632 |City number: 3455049, City name: Paranhos
# Processing Record 388 of 632 |City number: 582956, City name: Alekseyevka
# Processing Record 389 of 632 |City number: 2396518, City name: Port-Gentil
# Processing Record 390 of 632 |City number: 5184079, City name: Chester
# Processing Record 391 of 632 |City number: 2016733, City name: Shestakovo
# Processing Record 392 of 632 |City number: 3904906, City name: Santa Cruz de la Sierra
# Processing Record 393 of 632 |City number: 2643044, City name: Margate
# Processing Record 394 of 632 |City number: 3388847, City name: São Félix do Xingu
# Processing Record 395 of 632 |City number: 1246294, City name: Galle
# Processing Record 396 of 632 |City number: 608324, City name: Shetpe
# tuggurt: city not found. Skipping...
# Processing Record 397 of 632 |City number: 3893726, City name: Constitución
# Processing Record 398 of 632 |City number: 2742416, City name: Barcelos
# Processing Record 399 of 632 |City number: 1568510, City name: Rach Gia
# Processing Record 400 of 632 |City number: 2035707, City name: Mujiayingzi
# Processing Record 401 of 632 |City number: 1784841, City name: Zhaotong
# Processing Record 402 of 632 |City number: 1283285, City name: Jumla
# Processing Record 403 of 632 |City number: 1692650, City name: Pugo
# Processing Record 404 of 632 |City number: 1082243, City name: Ambilobe
# Processing Record 405 of 632 |City number: 2135517, City name: Norsup
# Processing Record 406 of 632 |City number: 6164499, City name: The Pas
# Processing Record 407 of 632 |City number: 5134295, City name: Rome
# kamenskoye: city not found. Skipping...
# Processing Record 408 of 632 |City number: 1524325, City name: Ekibastuz
# Processing Record 409 of 632 |City number: 1714733, City name: Dingle
# Processing Record 410 of 632 |City number: 5746545, City name: Portland
# Processing Record 411 of 632 |City number: 1526041, City name: Atasū
# samusu: city not found. Skipping...
# Processing Record 412 of 632 |City number: 6144312, City name: Sept-Îles
# Processing Record 413 of 632 |City number: 2253354, City name: Dakar
# Processing Record 414 of 632 |City number: 2644668, City name: Leicester
# Processing Record 415 of 632 |City number: 1058381, City name: Morondava
# Processing Record 416 of 632 |City number: 2632287, City name: Dalvik
# Processing Record 417 of 632 |City number: 897045, City name: Solwezi
# Processing Record 418 of 632 |City number: 4255151, City name: Bud
# Processing Record 419 of 632 |City number: 4019152, City name: Aguililla
# Processing Record 420 of 632 |City number: 933726, City name: Hukuntsi
# Processing Record 421 of 632 |City number: 2270385, City name: Camacha
# Processing Record 422 of 632 |City number: 779622, City name: Havøysund
# Processing Record 423 of 632 |City number: 3843123, City name: Neuquén
# Processing Record 424 of 632 |City number: 3128071, City name: Betanzos
# Processing Record 425 of 632 |City number: 2039557, City name: Khasan
# Processing Record 426 of 632 |City number: 2019867, City name: Mokhsogollokh
# Processing Record 427 of 632 |City number: 2208248, City name: Kaitangata
# Processing Record 428 of 632 |City number: 5268253, City name: Racine
# Processing Record 429 of 632 |City number: 609404, City name: Khromtau
# Processing Record 430 of 632 |City number: 363656, City name: Yambio
# Processing Record 431 of 632 |City number: 3354077, City name: Opuwo
# Processing Record 432 of 632 |City number: 3855075, City name: General Pico
# Processing Record 433 of 632 |City number: 1277527, City name: Balotra
# Processing Record 434 of 632 |City number: 4711647, City name: Mineral Wells
# Processing Record 435 of 632 |City number: 576195, City name: Bizhbulyak
# bolungarvik: city not found. Skipping...
# Processing Record 436 of 632 |City number: 5896969, City name: Beaverlodge
# Processing Record 437 of 632 |City number: 2092164, City name: Lorengau
# Processing Record 438 of 632 |City number: 3175445, City name: Isernia
# Processing Record 439 of 632 |City number: 2401495, City name: Booué
# Processing Record 440 of 632 |City number: 3465329, City name: Coruripe
# Processing Record 441 of 632 |City number: 3520994, City name: Puerto Escondido
# jahrom: city not found. Skipping...
# Processing Record 442 of 632 |City number: 3030142, City name: Briançon
# Processing Record 443 of 632 |City number: 3665202, City name: Aripuanã
# Processing Record 444 of 632 |City number: 7290171, City name: Plaster Rock
# Processing Record 445 of 632 |City number: 3397967, City name: Itaituba
# Processing Record 446 of 632 |City number: 1185095, City name: Teknāf
# Processing Record 447 of 632 |City number: 4047434, City name: Russell
# Processing Record 448 of 632 |City number: 2027296, City name: Aykhal
# Processing Record 449 of 632 |City number: 5972291, City name: Havre-St-Pierre
# Processing Record 450 of 632 |City number: 292968, City name: Abu Dhabi
# Processing Record 451 of 632 |City number: 4131116, City name: Siloam Springs
# Processing Record 452 of 632 |City number: 2184707, City name: Wanaka
# Processing Record 453 of 632 |City number: 2377457, City name: Nouadhibou
# Processing Record 454 of 632 |City number: 3602066, City name: San José de Río Tinto
# Processing Record 455 of 632 |City number: 3422683, City name: Kangaatsiaq
# Processing Record 456 of 632 |City number: 2436400, City name: Ati
# Processing Record 457 of 632 |City number: 5321473, City name: Winslow
# Processing Record 458 of 632 |City number: 2381334, City name: Atar
# Processing Record 459 of 632 |City number: 2028164, City name: Deputatsky
# Processing Record 460 of 632 |City number: 2013392, City name: Vilyuysk
# Processing Record 461 of 632 |City number: 6111867, City name: Port Hawkesbury
# Processing Record 462 of 632 |City number: 2181625, City name: Te Anau
# Processing Record 463 of 632 |City number: 1234633, City name: Moratuwa
# Processing Record 464 of 632 |City number: 2644605, City name: Lerwick
# Processing Record 465 of 632 |City number: 1153035, City name: Kathu
# Processing Record 466 of 632 |City number: 2514651, City name: Los Llanos de Aridane
# Processing Record 467 of 632 |City number: 1623197, City name: Tual
# Processing Record 468 of 632 |City number: 155743, City name: Lugoba
# Processing Record 469 of 632 |City number: 2967856, City name: Vitry-le-François
# Processing Record 470 of 632 |City number: 509017, City name: Pleshanovo
# Processing Record 471 of 632 |City number: 5116602, City name: Endicott
# Processing Record 472 of 632 |City number: 342190, City name: Bichena
# Processing Record 473 of 632 |City number: 1636426, City name: Manggar
# Processing Record 474 of 632 |City number: 3193935, City name: Osijek
# Processing Record 475 of 632 |City number: 3359638, City name: Walvis Bay
# Processing Record 476 of 632 |City number: 2338660, City name: Yaan
# Processing Record 477 of 632 |City number: 3576994, City name: Cockburn Town
# Processing Record 478 of 632 |City number: 2012956, City name: Yerbogachën
# Processing Record 479 of 632 |City number: 1687894, City name: Santa Rosa
# Processing Record 480 of 632 |City number: 572520, City name: Borisoglebskiy
# Processing Record 481 of 632 |City number: 2127202, City name: Anadyr
# Processing Record 482 of 632 |City number: 4470244, City name: Havelock
# vaitupu: city not found. Skipping...
# Processing Record 483 of 632 |City number: 1214488, City name: Meulaboh
# Processing Record 484 of 632 |City number: 1289828, City name: Wakema
# Processing Record 485 of 632 |City number: 1630058, City name: Karaton
# Processing Record 486 of 632 |City number: 1501377, City name: Kungurtug
# Processing Record 487 of 632 |City number: 2020311, City name: Mamakan
# Processing Record 488 of 632 |City number: 70979, City name: Sayyan
# jomalig: city not found. Skipping...
# Processing Record 489 of 632 |City number: 2656752, City name: Aviemore
# Processing Record 490 of 632 |City number: 2067119, City name: Mandurah
# Processing Record 491 of 632 |City number: 124291, City name: Mehrān
# nguiu: city not found. Skipping...
# Processing Record 492 of 632 |City number: 4033356, City name: Tiarei
# Processing Record 493 of 632 |City number: 2293428, City name: Adiaké
# Processing Record 494 of 632 |City number: 3674292, City name: Mosquera
# Processing Record 495 of 632 |City number: 3934707, City name: Mollendo
# Processing Record 496 of 632 |City number: 563471, City name: Energetik
# Processing Record 497 of 632 |City number: 1140025, City name: Herat Province
# Processing Record 498 of 632 |City number: 3013748, City name: Hauterive
# Processing Record 499 of 632 |City number: 4696788, City name: Hays
# Processing Record 500 of 632 |City number: 2229798, City name: Kousséri
# Processing Record 501 of 632 |City number: 80509, City name: Al Bardīyah
# Processing Record 502 of 632 |City number: 778707, City name: Mehamn
# Processing Record 503 of 632 |City number: 1648082, City name: Boyolangu
# Processing Record 504 of 632 |City number: 2145214, City name: Victoria Point
# Processing Record 505 of 632 |City number: 1337610, City name: Thinadhoo
# hihifo: city not found. Skipping...
# Processing Record 506 of 632 |City number: 3454005, City name: Piaçabuçu
# Processing Record 507 of 632 |City number: 1254709, City name: Tezu
# Processing Record 508 of 632 |City number: 1503037, City name: Kodinsk
# Processing Record 509 of 632 |City number: 6067747, City name: Matagami
# Processing Record 510 of 632 |City number: 1636544, City name: Manado
# Processing Record 511 of 632 |City number: 2669047, City name: Timrå
# Processing Record 512 of 632 |City number: 4845585, City name: Westport
# Processing Record 513 of 632 |City number: 4734350, City name: Stephenville
# Processing Record 514 of 632 |City number: 3389622, City name: Santa Helena
# Processing Record 515 of 632 |City number: 236950, City name: Obo
# Processing Record 516 of 632 |City number: 2138522, City name: Poya
# Processing Record 517 of 632 |City number: 605155, City name: Kiruna
# Processing Record 518 of 632 |City number: 129933, City name: Jūybār
# Processing Record 519 of 632 |City number: 2172880, City name: Byron Bay
# Processing Record 520 of 632 |City number: 5915327, City name: Cap-aux-Meules
# wahran: city not found. Skipping...
# Processing Record 521 of 632 |City number: 3160100, City name: Brekstad
# Processing Record 522 of 632 |City number: 5524849, City name: Lamesa
# Processing Record 523 of 632 |City number: 2077895, City name: Alice Springs
# Processing Record 524 of 632 |City number: 1261227, City name: Nokha
# Processing Record 525 of 632 |City number: 3372472, City name: Vila Franca do Campo
# sorvag: city not found. Skipping...
# mrirt: city not found. Skipping...
# Processing Record 526 of 632 |City number: 5364271, City name: Laguna
# Processing Record 527 of 632 |City number: 1065158, City name: Farafangana
# Processing Record 528 of 632 |City number: 1264976, City name: Leh
# Processing Record 529 of 632 |City number: 780687, City name: Berlevåg
# Processing Record 530 of 632 |City number: 1028434, City name: Quelimane
# Processing Record 531 of 632 |City number: 2447513, City name: Arlit
# Processing Record 532 of 632 |City number: 5733351, City name: Jackson
# zhanatas: city not found. Skipping...
# Processing Record 533 of 632 |City number: 2094027, City name: Kieta
# Processing Record 534 of 632 |City number: 3629710, City name: Puerto Ayacucho
# Processing Record 535 of 632 |City number: 1529102, City name: Ürümqi
# Processing Record 536 of 632 |City number: 2037485, City name: Erenhot
# Processing Record 537 of 632 |City number: 157429, City name: Kilindoni
# Processing Record 538 of 632 |City number: 4034438, City name: Haapiti
# Processing Record 539 of 632 |City number: 986717, City name: Kruisfontein
# Processing Record 540 of 632 |City number: 5206379, City name: Pittsburgh
# karauzyak: city not found. Skipping...
# Processing Record 541 of 632 |City number: 1630935, City name: Polewali
# Processing Record 542 of 632 |City number: 571702, City name: Bratskoye
# nizhneyansk: city not found. Skipping...
# Processing Record 543 of 632 |City number: 2132606, City name: Samarai
# Processing Record 544 of 632 |City number: 6111862, City name: Port Hardy
# Processing Record 545 of 632 |City number: 3894426, City name: Coyhaique
# ruatoria: city not found. Skipping...
# urfa: city not found. Skipping...
# bolshoye sorokino: city not found. Skipping...
# Processing Record 546 of 632 |City number: 3996647, City name: Mapimí
# Processing Record 547 of 632 |City number: 1624041, City name: Ternate
# Processing Record 548 of 632 |City number: 3435910, City name: Buenos Aires
# Processing Record 549 of 632 |City number: 1805733, City name: Jinchang
# Processing Record 550 of 632 |City number: 634093, City name: Tornio
# Processing Record 551 of 632 |City number: 3698304, City name: Chimbote
# Processing Record 552 of 632 |City number: 1272140, City name: Dwārka
# Processing Record 553 of 632 |City number: 974670, City name: Mondlo
# Processing Record 554 of 632 |City number: 2025256, City name: Chumikan
# Processing Record 555 of 632 |City number: 3141667, City name: Roald
# Processing Record 556 of 632 |City number: 3170346, City name: Pombia
# Processing Record 557 of 632 |City number: 2427036, City name: Ngama
# Processing Record 558 of 632 |City number: 3579925, City name: St. George's
# Processing Record 559 of 632 |City number: 2801226, City name: Boussu
# Processing Record 560 of 632 |City number: 1501321, City name: Kurgan
# Processing Record 561 of 632 |City number: 2755485, City name: Goedereede
# Processing Record 562 of 632 |City number: 111822, City name: Yazd
# Processing Record 563 of 632 |City number: 2514301, City name: Mahon
# Processing Record 564 of 632 |City number: 2150163, City name: Sawtell
# Processing Record 565 of 632 |City number: 128477, City name: Kashan
# Processing Record 566 of 632 |City number: 3444105, City name: San Matías
# Processing Record 567 of 632 |City number: 1861416, City name: Ishigaki
# Processing Record 568 of 632 |City number: 104515, City name: Makkah al Mukarramah
# Processing Record 569 of 632 |City number: 2255304, City name: Sémbé
# Processing Record 570 of 632 |City number: 124274, City name: Mahrīz
# Processing Record 571 of 632 |City number: 1728675, City name: Balabac
# Processing Record 572 of 632 |City number: 477424, City name: Vad
# Processing Record 573 of 632 |City number: 2269594, City name: Cascais
# Processing Record 574 of 632 |City number: 4231997, City name: Avera
# Processing Record 575 of 632 |City number: 3647444, City name: Calabozo
# Processing Record 576 of 632 |City number: 2961459, City name: Skibbereen
# Processing Record 577 of 632 |City number: 1638775, City name: Payo
# Processing Record 578 of 632 |City number: 2986732, City name: Ploemeur
# Processing Record 579 of 632 |City number: 5882953, City name: Aklavik
# Processing Record 580 of 632 |City number: 2464915, City name: Sousse
# Processing Record 581 of 632 |City number: 1512210, City name: Abatskiy

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display the DataFrame
for date_ in meteorology_cities['Date']:
    meteorology_cities['Date'] = datetime.fromtimestamp(date_).strftime('%m/%d/%Y')
# Export the city data into a .csv.
meteorology_cities.to_csv("output_data/meteorology_of_cities.csv", index=False, header=True)
meteorology_cities
# Out:
#               City      Lat       Lng   Temp  Humidity  Cloudiness  \
# 0        Caravelas -17.7125  -39.2481  75.85        92         100
# 1        Hay River  60.8156 -115.7999 -31.00        61         100
# 2    Mar del Plata -38.0023  -57.5575  59.81        94          90
# 3         Moussoro  13.6408   16.4901  66.78        22           3
# 4       Nikolskoye  59.7035   30.7861  13.93        86          90
# ..             ...      ...       ...    ...       ...         ...
# 576           Payo  -3.7508  103.6372  75.67        89         100
# 577       Ploemeur  47.7333   -3.4333  35.55        80          90
# 578        Aklavik  68.2191 -135.0107 -22.95        76         100
# 579         Sousse  35.8254   10.6370  55.24        77          40
# 580       Abatskiy  56.2875   70.4555   5.95        93         100
#
#      Wind Speed Country        Date
# 0          5.86      BR  02/07/2021
# 1          4.61      CA  02/07/2021
# 2         18.41      AR  02/07/2021
# 3         11.10      TD  02/07/2021
# 4         11.18      RU  02/07/2021
# ..          ...     ...         ...
# 576        2.21      ID  02/07/2021
# 577        9.22      FR  02/07/2021
# 578        8.05      CA  02/07/2021
# 579        8.05      TN  02/07/2021
# 580       13.11      RU  02/07/2021
#
# [581 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
Weather_cities_statistic = meteorology_cities.describe(percentiles=None, include=None, exclude=None, datetime_is_numeric=False)
Weather_cities_statistic
# Out:
#               Lat         Lng        Temp    Humidity  Cloudiness  Wind Speed
# count  581.000000  581.000000  581.000000  581.000000  581.000000  581.000000
# mean    19.843859   16.709550   48.922358   72.724613   53.461274    8.497522
# std     33.044992   88.637965   31.890299   19.663810   41.408278    6.107434
# min    -54.800000 -175.200000  -36.690000    8.000000    0.000000    0.310000
# 25%     -6.216700  -61.748500   26.600000   63.000000    2.000000    3.960000
# 50%     21.461200   20.259700   60.800000   78.000000   62.000000    6.910000
# 75%     46.906500   92.305800   74.800000   87.000000   99.000000   11.500000
# max     78.218600  179.316700   89.600000  100.000000  100.000000   44.870000

# %%
#  Get the indices of cities that have humidity over 100%
#city_Hum100 =  meteorology_cities.index[meteorology_cities['Humidity'] > 100 ].tolist()
city_Hum100 = meteorology_cities[(meteorology_cities['Humidity'] > 100)]
if len(city_Hum100) == 0:
    clean_city_data = meteorology_cities.copy()
    print(f"Skip this step if there are no cities that have humidity > 100%.")
    print(city_Hum100.index)
else:
    clean_city_data = meteorology_cities[(meteorology_cities['Humidity'] <= 100)]
    clean_city_data_statistic = clean_city_data.describe(percentiles=None, include=None, exclude=None, datetime_is_numeric=False)
    print(f"Indices of cities that have humidity over 100%.: {city_Hum100.index}")
    print(f"=========================================================================")
    print(f"{clean_city_data_statistic}")
# Out:
# Skip this step if there are no cities that have humidity > 100%.
# Int64Index([], dtype='int64')

# %%
#which we call "clean_city_data"
clean_city_data
# Out:
#               City      Lat       Lng   Temp  Humidity  Cloudiness  \
# 0        Caravelas -17.7125  -39.2481  75.85        92         100
# 1        Hay River  60.8156 -115.7999 -31.00        61         100
# 2    Mar del Plata -38.0023  -57.5575  59.81        94          90
# 3         Moussoro  13.6408   16.4901  66.78        22           3
# 4       Nikolskoye  59.7035   30.7861  13.93        86          90
# ..             ...      ...       ...    ...       ...         ...
# 576           Payo  -3.7508  103.6372  75.67        89         100
# 577       Ploemeur  47.7333   -3.4333  35.55        80          90
# 578        Aklavik  68.2191 -135.0107 -22.95        76         100
# 579         Sousse  35.8254   10.6370  55.24        77          40
# 580       Abatskiy  56.2875   70.4555   5.95        93         100
#
#      Wind Speed Country        Date
# 0          5.86      BR  02/07/2021
# 1          4.61      CA  02/07/2021
# 2         18.41      AR  02/07/2021
# 3         11.10      TD  02/07/2021
# 4         11.18      RU  02/07/2021
# ..          ...     ...         ...
# 576        2.21      ID  02/07/2021
# 577        9.22      FR  02/07/2021
# 578        8.05      CA  02/07/2021
# 579        8.05      TN  02/07/2021
# 580       13.11      RU  02/07/2021
#
# [581 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
date = clean_city_data['Date'].max()
plt.style.use('seaborn')
x = clean_city_data['Lat']
y = clean_city_data['Temp']
ratio = clean_city_data['Temp'] #[1, 0.53, 2, 0.76, 0.5, 2.125, 0.56, 1.28, 1.09, 1.02]
plt.scatter(x, y, s=100, c=ratio, cmap="cool_r", edgecolor="#FFD500", linewidth=1, alpha=0.75)
plt.title(f"Latitude of cities vs Temperature °F | {date}", fontsize = "12")
plt.xlabel(f"Latitude", fontsize="14")
plt.ylabel(f"Temperature °F", fontsize="14")
cbar = plt.colorbar()
cbar.set_label('Latitud vs max Temperature')
plt.savefig("output_data/Fig1_Lat_vs_Tem.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
date = clean_city_data['Date'].max()
plt.style.use('seaborn')
x = clean_city_data['Lat']
y = clean_city_data['Humidity']
plt.scatter(x, y, s=100, c=ratio, cmap="RdYlBu_r", edgecolor="#FFD500", linewidth=1, alpha=0.75)
plt.title(f"Latitude of cities vs Humidity | {date}", fontsize = "12")
plt.xlabel(f"Latitude", fontsize="14")
plt.ylabel(f"Humidity", fontsize="14")
cbar= plt.colorbar()
cbar.set_label('Latitud vs Humidity')
plt.savefig("output_data/Fig2_Lat_vs_Hum.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
date = clean_city_data['Date'].max()
plt.style.use('seaborn')
x = clean_city_data['Lat']
y = clean_city_data['Cloudiness']
plt.scatter(x, y, s=100, c=ratio, cmap="gist_gray_r", edgecolor="grey", linewidth=1, alpha=0.75);
plt.title(f"Latitude of cities vs Cloudiness | {date}", fontsize = "12")
plt.xlabel(f"Latitude", fontsize="14")
plt.ylabel(f"Cloudiness", fontsize="14")
cbar= plt.colorbar()
cbar.set_label('Latitud vs Cloudiness')
plt.savefig("output_data/Fig3_Lat_vs_Clou.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
date = clean_city_data['Date'].max()
plt.style.use('seaborn')
x = clean_city_data['Lat']
y = clean_city_data['Wind Speed']
plt.scatter(x, y, s=100, c=ratio, cmap="winter_r", edgecolor="grey", linewidth=1, alpha=0.75);
plt.title(f"Latitude of cities vs Wind Speed (miles/hour) | {date}", fontsize = "12")
plt.xlabel(f"Latitude", fontsize="14")
plt.ylabel(f"Wind Speed (miles/hour)", fontsize="14")
cbar = plt.colorbar()
cbar.set_label(f"Latitud vs Wind Speed (miles/hour)")
plt.savefig("output_data/Fig4_Lat_vs_WS.png")

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Northern Hemisphere = Latitude between 0 ° and 90 °: Northern Hemisphere
Northern_city_data = meteorology_cities[(meteorology_cities['Lat'] > 0)]
date = Northern_city_data['Date'].max()
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_north=Northern_city_data['Lat']
y_north=Northern_city_data['Temp']
ratio_Northern = Northern_city_data['Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_north, y_north)
regress_values_north = x_north * slope + intercept
line_North = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation_North = round(rvalue,3)
plt.style.use('seaborn')
Norte = plt.scatter(x_north, y_north, s=100, c=ratio_Northern, cmap="cool_r", edgecolor="#FFD500", linewidth=1, alpha=0.75);
plt.plot(x_north,regress_values_north,"r-")
plt.annotate(line_North,(50,80),fontsize=14, color="red")
plt.title(f"North Latitude of Cities vs. Temperature °F | {date}", fontsize = "12")
plt.xlabel(f"Latitude", size=14)
plt.ylabel(f"Max Temperature (°F)", size=14)
plt.tight_layout()
cbar= plt.colorbar()
cbar.set_label('North Latitud vs Max Temp °F')
plt.savefig("output_data/Fig5_North_Lat_vs_temp_reg.png")
plt.show();
print(f"the intercept :{round(intercept,3)}");
print(f"correlation:{round(correlation_North,3)}");
print(f"Lat linear regression model :{line_North}");
print(f"===============================================")
print(f" I observe that both variables have a very high inverse (negative) correlation \
based on the value: {correlation_North}, that is {round(correlation_North*100,2)}%, which \
indicates that are inversely proportional, as long as the Latitude \
decreases, approaches 0° (Equator), the Temeprature °F increases in the same proportion.")
# Out:
# the intercept :88.643
# correlation:-0.853
# Lat linear regression model :y = -1.34x + 88.64
# ===============================================
#  I observe that both variables have a very high inverse (negative) correlation based on the value: -0.853, that is -85.3%, which indicates that are inversely proportional, as long as the Latitude decreases, approaches 0° (Equator), the Temeprature °F increases in the same proportion.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Southern Hemisphere = Latitude between 0 ° and -90 °: Southern Hemisphere
Southern_city_data = meteorology_cities[(meteorology_cities['Lat'] < 0)]
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression
date = Southern_city_data['Date'].max()
x_South=Southern_city_data['Lat']
y_South=Southern_city_data['Temp']
ratio_Southern = Southern_city_data['Temp'].index
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_South, y_South)
#print(f"the intercept :{round(intercept,2)}");
regress_values_South = x_South * slope + intercept
line_South = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation_South = round(rvalue,2)
plt.style.use('seaborn')
sur = plt.scatter(x_South, y_South, s=100, c=ratio_Southern, cmap="cool_r", edgecolor="#FFD500", linewidth=1, alpha=0.75);
plt.plot(x_South,regress_values_South,"r-")
plt.annotate(line_South,(-20,55),fontsize=14, color="red")
plt.title(f"South Latitude of Cities vs. Temperature°F| {date}", fontsize = "12")
plt.xlabel(f"Latitude", size=14)
plt.ylabel(f"Max Temperature (°F)", size=14)
plt.tight_layout()
cbar= plt.colorbar()
cbar.set_label('South Latitud vs Max Temp °F')
plt.savefig("output_data/Fig6_South_Lat_vs_temp_reg.png")
plt.show();
print(f"the intercept :{round(intercept,3)}");
print(f"correlation:{round(correlation_South,3)}");
print(f"Lat linear regression model :{line_South}");
print(f"==============================================")
print(f"There is a very high correlation based on the value {correlation_South}, that is: {round(correlation_South*100,2)}%, which \
indicates that they are directly proportional, while the Latitude increases, Lat approaches zero (Equator), \
the Temeprature °F also increases, in the same proportion.")
# Out:
# the intercept :80.754
# correlation:0.56
# Lat linear regression model :y = 0.35x + 80.75
# ==============================================
# There is a very high correlation based on the value 0.56, that is: 56.0%, which indicates that they are directly proportional, while the Latitude increases, Lat approaches zero (Equator), the Temeprature °F also increases, in the same proportion.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere = Latitude between 0 ° and 90 °: Northern Hemisphere
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
#Northern_city_data = meteorology_cities[(meteorology_cities['Lat'] > 0)]
date = Northern_city_data['Date'].max()
x_north=Northern_city_data['Lat']
y_north=Northern_city_data['Humidity']
ratio_Northern = Northern_city_data['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_north, y_north)
#print(f"the intercept :{round(intercept,2)}");
regress_values_north = x_north * slope + intercept
line_North = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation_North = round(rvalue,3)
plt.style.use('seaborn')
Norte = plt.scatter(x_north, y_north, s=100, c=ratio_Northern, cmap="RdYlBu_r", edgecolor="#FFD500", linewidth=1, alpha=0.75);
plt.plot(x_north,regress_values_north,"r-")
plt.annotate(line_North,(50,20),fontsize=14, color="red")
plt.title(f"North Latitude of Cities vs. Humidity % | {date}", fontsize = "12")
plt.xlabel(f"Latitude", size=14)
plt.ylabel(f"Humidity %", size=14)
plt.tight_layout()
cbar= plt.colorbar()
cbar.set_label('North Latitud vs Humidity %')
plt.savefig("output_data/Fig7_North_Lat_vs_Hum_reg.png") 
plt.show();
print(f"the intercept :{round(intercept,2)}");
print(f"correlation:{round(correlation_North,3)}");
print(f"Lat linear regression model :{line_North}");
print(f"=============================================")
print(f"There is an absence of correlation between Northern Hemisphere Latitude and Humidity %, \
the correlation value is {round(correlation_North*100,2)}%, although it is positive, it does not show a trend between both variables")
# Out:
# the intercept :61.88
# correlation:0.255
# Lat linear regression model :y = 0.26x + 61.88
# =============================================
# There is an absence of correlation between Northern Hemisphere Latitude and Humidity %, the correlation value is 25.5%, although it is positive, it does not show a trend between both variables

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Southern_city_data = meteorology_cities[(meteorology_cities['Lat'] < 0)]
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
date = Southern_city_data['Date'].max()
x_South=Southern_city_data['Lat']
y_South=Southern_city_data['Humidity']
ratio_Southern = Southern_city_data['Humidity'].index
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_South, y_South)
#print(f"the intercept :{round(intercept,2)}");
regress_values_South = x_South * slope + intercept
line_South = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation_South = round(rvalue,2)
plt.style.use('seaborn')
sur = plt.scatter(x_South, y_South, s=100, c=ratio_Southern, cmap="RdYlBu_r", edgecolor="#FFD500", linewidth=1, alpha=0.75);
plt.plot(x_South,regress_values_South,"r-")
plt.annotate(line_South,(-20,40),fontsize=14, color="red")
plt.title(f"South Latitude of Cities vs. Humidity % | {date}", fontsize = "12")
plt.xlabel(f"Latitude", size=14)
plt.ylabel(f"Humidity %", size=14)
plt.tight_layout()
cbar= plt.colorbar()
cbar.set_label('South Latitud vs Humidity %')
plt.savefig("output_data/Fig8_South_Lat_vs_Hum_reg.png") 
plt.show();
print(f"the intercept :{round(intercept,3)}");
print(f"correlation:{round(correlation_South,3)}");
print(f"Lat linear regression model :{line_South}");
print(f"==============================================")
print(f"There is an absence of correlation between Southern Hemisphere Latitude and Humidity %, \
the correlation value is {round(correlation_South*100,2)}%, although it is positive, it does not show a trend between both variables")
# Out:
# the intercept :82.741
# correlation:0.34
# Lat linear regression model :y = 0.38x + 82.74
# ==============================================
# There is an absence of correlation between Southern Hemisphere Latitude and Humidity %, the correlation value is 34.0%, although it is positive, it does not show a trend between both variables

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
date = Northern_city_data['Date'].max()
x_north=Northern_city_data['Lat']
y_north=Northern_city_data['Cloudiness']
ratio_Northern = Northern_city_data['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_north, y_north)
#print(f"the intercept :{round(intercept,2)}");
regress_values_north = x_north * slope + intercept
line_North = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation_North = round(rvalue,3)
plt.style.use('seaborn')
Norte = plt.scatter(x_north, y_north, s=100, c=ratio_Northern, cmap="gist_gray_r", edgecolor="grey", linewidth=1, alpha=0.75);
plt.plot(x_north,regress_values_north,"r-")
plt.annotate(line_North,(50,20),fontsize=14, color="red")
plt.title(f"North Latitude of Cities vs. Cloudiness % | {date}", fontsize = "12")
plt.xlabel(f"Latitude", size=14)
plt.ylabel(f"Cloudiness %", size=14)
plt.tight_layout()
cbar= plt.colorbar()
cbar.set_label('North Latitud vs Cloudiness %')
plt.savefig("output_data/Fig9_North_Lat_vs_Clo_reg.png") 
plt.show();
print(f"the intercept :{round(intercept,2)}");
print(f"correlation:{round(correlation_North,3)}");
print(f"Lat linear regression model :{line_North}");
print(f"==============================================")
print(f"There is an absence of correlation (no correlation) between Latitude and Cloudiness %, \
the correlation value is {round(correlation_North*100,2)}%, although it is positive")
# Out:
# the intercept :40.88
# correlation:0.138
# Lat linear regression model :y = 0.28x + 40.88
# ==============================================
# There is an absence of correlation (no correlation) between Latitude and Cloudiness %, the correlation value is 13.8%, although it is positive

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
date = Southern_city_data['Date'].max()
x_South=Southern_city_data['Lat']
y_South=Southern_city_data['Cloudiness']
ratio_Southern = Southern_city_data['Cloudiness'].index
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_South, y_South)
#print(f"the intercept :{round(intercept,2)}");
regress_values_South = x_South * slope + intercept
line_South = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation_South = round(rvalue,2)
plt.style.use('seaborn')
sur = plt.scatter(x_South, y_South, s=100, c=ratio_Southern, cmap="gist_gray_r", edgecolor="grey", linewidth=1, alpha=0.75);
plt.plot(x_South,regress_values_South,"r-")
plt.annotate(line_South,(-20,40),fontsize=14, color="red")
plt.title(f"South Latitude of Cities vs. Cloudiness % | {date}", fontsize = "12")
plt.xlabel(f"Latitude", size=14)
plt.ylabel(f"Cloudiness %", size=14)
plt.tight_layout()
cbar= plt.colorbar()
cbar.set_label('South Latitud vs Cloudiness %')
plt.savefig("output_data/Fig10_South_Lat_vs_Clo_reg.png")
plt.show();
print(f"the intercept :{round(intercept,3)}");
print(f"correlation:{round(correlation_South,3)}");
print(f"Lat linear regression model :{line_South}");
print(f"==============================================")
print(f"There is no correlation between Latitude and Cloudiness %, \
the correlation value is {round(correlation_South*100,2)}%, although it is positive")
# Out:
# the intercept :71.717
# correlation:0.23
# Lat linear regression model :y = 0.67x + 71.72
# ==============================================
# There is no correlation between Latitude and Cloudiness %, the correlation value is 23.0%, although it is positive

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
date = Northern_city_data['Date'].max()
x_north=Northern_city_data['Lat']
y_north=Northern_city_data['Wind Speed']
ratio_Northern = Northern_city_data['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_north, y_north)
#print(f"the intercept :{round(intercept,2)}");
regress_values_north = x_north * slope + intercept
line_North = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation_North = round(rvalue,3)
plt.style.use('seaborn')
Norte = plt.scatter(x_north, y_north, s=100, c=ratio_Northern, cmap="winter_r", edgecolor="grey", linewidth=1, alpha=0.75);
plt.plot(x_north,regress_values_north,"r-")
plt.annotate(line_North,(50,20),fontsize=14, color="red")
plt.title(f"North Latitude of Cities vs. Wind Speed (miles/hour) | {date}", fontsize = "12")
plt.xlabel(f"Latitude", size=14)
plt.ylabel(f"Wind Speed (miles/hour)", size=14)
plt.tight_layout()
cbar= plt.colorbar()
cbar.set_label('North Latitud vs Wind Speed MPH')
plt.savefig("output_data/Fig11_North_Lat_vs_WS_reg.png")
plt.show();
print(f"the intercept :{round(intercept,2)}");
print(f"correlation:{round(correlation_North,3)}");
print(f"Lat linear regression model :{line_North}");
print(f"==============================================")
print(f"There is a low correlation between latitude and wind speed, \
the correlation value is {round(correlation_North*100,2)}%, although it is positive \
Looking at the graph and the agglomeration of the points, it seems that there is a marked \
correlation, but analyzing the regression line, this correlation is low, \
denoting that if the latitude separates from the equator, the wind is moderately rising.")
# Out:
# the intercept :6.37
# correlation:0.211
# Lat linear regression model :y = 0.07x + 6.37
# ==============================================
# There is a low correlation between latitude and wind speed, the correlation value is 21.1%, although it is positive Looking at the graph and the agglomeration of the points, it seems that there is a marked correlation, but analyzing the regression line, this correlation is low, denoting that if the latitude separates from the equator, the wind is moderately rising.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
date = Southern_city_data['Date'].max()
x_South=Southern_city_data['Lat']
y_South=Southern_city_data['Wind Speed']
ratio_Southern = Southern_city_data['Wind Speed'].index
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_South, y_South)
#print(f"the intercept :{round(intercept,2)}");
regress_values_South = x_South * slope + intercept
line_South = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation_South = round(rvalue,2)
plt.style.use('seaborn')
sur = plt.scatter(x_South, y_South, s=100, c=ratio_Southern, cmap="winter_r", edgecolor="grey", linewidth=1, alpha=0.75);
plt.plot(x_South,regress_values_South,"r-")
plt.annotate(line_South,(-20,20),fontsize=14, color="red")
plt.title(f"South Latitude of Cities vs. Wind Speed Miles/Hour % | {date}", fontsize = "12")
plt.xlabel(f"Latitude", size=14)
plt.ylabel(f"Wind Speed Miles/Hour", size=14)
plt.tight_layout()
cbar= plt.colorbar()
cbar.set_label('South Latitud vs Wind Speed Miles/Hour')
plt.savefig("output_data/Fig12_South_Lat_vs_WS_reg.png")
plt.show();
print(f"the intercept :{round(intercept,3)}");
print(f"correlation:{round(correlation_South,3)}");
print(f"Lat linear regression model :{line_South}");
print(f"==============================================")
print(f"There is a low correlation between latitude and wind speed, \
the correlation value is {round(correlation_South*100,2)}%, is negative, \
the low correlation suggests that as you approach zero latitude, the equator, \
the wind speed decreases very slowly.")
# Out:
# the intercept :5.688
# correlation:-0.25
# Lat linear regression model :y = -0.1x + 5.69
# ==============================================
# There is a low correlation between latitude and wind speed, the correlation value is -25.0%, is negative, the low correlation suggests that as you approach zero latitude, the equator, the wind speed decreases very slowly.
