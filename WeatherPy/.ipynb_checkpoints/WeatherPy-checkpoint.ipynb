# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime 
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
Number_of_cities = len(cities)
Number_of_cities
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#City	Lat	Lng	Max Temp	Humidity	Cloudiness	Wind Speed	Country	Date
#city_results = []
#Index_cities=[]

City_Number = []
City_Name = []
City_Lat = []
City_Lng = []
City_MaxTemp = []
City_Humidity = []
City_Cloudiness = []
City_WindSpeed = []
City_Country = []
City_Date = []
Count_Record = 0
#for city in cities:   

#weather_api_key= "a160fd00bbc7c7caddb54e2757ff85b2"
#city_ejempo=['London','Melbourne','Alaska','Jazan','Caracas','Harare','El Junquito','New Orleans',"GTY77","Maracay","Washington", "Pensilvanya", "Palita", "guarenas", "Atlanta", "Bogota"]

for city in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial"
    #print(url) 
    Req_weather_city = requests.get(url).json()
    if (Req_weather_city["cod"]==200):
        Count_Record = Count_Record + 1
        City_Number.append(Req_weather_city['id'])
        City_Name.append(Req_weather_city['name'])
        City_Lat.append(Req_weather_city['coord']['lat'])
        City_Lng.append(Req_weather_city['coord']['lon'])
        City_MaxTemp.append(Req_weather_city['main']['temp'])
        City_Humidity.append(Req_weather_city['main']['humidity'])
        City_Cloudiness.append(Req_weather_city['clouds']['all'])
        City_WindSpeed.append(Req_weather_city['wind']['speed'])
        City_Country.append(Req_weather_city['sys']['country'])
        City_Date.append(Req_weather_city['dt'])
        print(f"Processing Record {Count_Record} of {Number_of_cities} |City number: {Req_weather_city['id']}, City name: {Req_weather_city['name']}")
    else: 
        #{"cod":"404","message":"city not found"}
        print(f"{city}: {Req_weather_city['message']}. Skipping...")

weather_dict = {
    "City": City_Name,
    "Lat": City_Lat,
    "Lng":City_Lng,
    "Temp": City_MaxTemp,
    "Humidity":City_Humidity,
    "Cloudiness":City_Cloudiness,
    "Wind Speed":City_WindSpeed,
    "Country":City_Country,
    "Date":City_Date 
}
meteorology_cities = pd.DataFrame(weather_dict)
# Out:
# Processing Record 1 of 613 |City number: 4944903, City name: Nantucket
# Processing Record 2 of 613 |City number: 86049, City name: Jalu
# Processing Record 3 of 613 |City number: 986717, City name: Kruisfontein
# Processing Record 4 of 613 |City number: 6185377, City name: Yellowknife
# Processing Record 5 of 613 |City number: 4030556, City name: Rikitea
# Processing Record 6 of 613 |City number: 1734798, City name: Semenyih
# Processing Record 7 of 613 |City number: 6201424, City name: Mataura
# Processing Record 8 of 613 |City number: 3833367, City name: Ushuaia
# Processing Record 9 of 613 |City number: 2020591, City name: Magdagachi
# Processing Record 10 of 613 |City number: 4017152, City name: Benjamín Hill
# Processing Record 11 of 613 |City number: 2208248, City name: Kaitangata
# Processing Record 12 of 613 |City number: 3355672, City name: Lüderitz
# Processing Record 13 of 613 |City number: 2163355, City name: Hobart
# Processing Record 14 of 613 |City number: 2017155, City name: Saskylakh
# Processing Record 15 of 613 |City number: 2110227, City name: Butaritari
# Processing Record 16 of 613 |City number: 933995, City name: Souillac
# Processing Record 17 of 613 |City number: 5106841, City name: Albany
# Processing Record 18 of 613 |City number: 5367788, City name: Lompoc
# Processing Record 19 of 613 |City number: 2779229, City name: Friesach
# Processing Record 20 of 613 |City number: 2126710, City name: Beringovskiy
# Processing Record 68 of 613 |City number: 777019, City name: Vardø
# Processing Record 69 of 613 |City number: 3698304, City name: Chimbote
# Processing Record 70 of 613 |City number: 778829, City name: Lyngseidet
# Processing Record 71 of 613 |City number: 4984075, City name: Alpena
# Processing Record 72 of 613 |City number: 935215, City name: Saint-Philippe
# Processing Record 73 of 613 |City number: 4036284, City name: Alofi
# Processing Record 74 of 613 |City number: 4031637, City name: Lavrentiya
# Processing Record 75 of 613 |City number: 5122534, City name: Jamestown
# Processing Record 76 of 613 |City number: 3382160, City name: Cayenne
# Processing Record 77 of 613 |City number: 2074865, City name: Carnarvon
# Processing Record 78 of 613 |City number: 2071860, City name: Esperance
# Processing Record 79 of 613 |City number: 2173323, City name: Bundaberg
# Processing Record 80 of 613 |City number: 3985710, City name: Cabo San Lucas
# Processing Record 81 of 613 |City number: 2137773, City name: Vao
# Processing Record 82 of 613 |City number: 6165406, City name: Thompson
# Processing Record 83 of 613 |City number: 3521108, City name: Progreso
# Processing Record 84 of 613 |City number: 2126682, City name: Bilibino
# Processing Record 85 of 613 |City number: 108410, City name: Riyadh
# Processing Record 86 of 613 |City number: 2264557, City name: Ponta do Sol
# Processing Record 87 of 613 |City number: 1272411, City name: Dondaicha
# Processing Record 88 of 613 |City number: 2070998, City name: Geraldton
# Processing Record 89 of 613 |City number: 3361934, City name: Saldanha
# Processing Record 90 of 613 |City number: 3894426, City name: Coyhaique
# Processing Record 91 of 613 |City number: 2090021, City name: Namatanai
# Processing Record 92 of 613 |City number: 1642773, City name: Japura
# Processing Record 93 of 613 |City number: 5380437, City name: Pacific Grove
# Processing Record 94 of 613 |City number: 5364271, City name: Laguna
# hendijan: city not found. Skipping...
# Processing Record 95 of 613 |City number: 2028462, City name: Ulaanbaatar
# Processing Record 96 of 613 |City number: 1651810, City name: Airai
# Processing Record 97 of 613 |City number: 3500957, City name: La Romana
# Processing Record 98 of 613 |City number: 3372707, City name: Ribeira Grande
# Processing Record 99 of 613 |City number: 2374583, City name: Bubaque
# mys shmidta: city not found. Skipping...
# Processing Record 100 of 613 |City number: 2137748, City name: Voh
# Processing Record 101 of 613 |City number: 1071296, City name: Antalaha
# Processing Record 102 of 613 |City number: 3443061, City name: Chui
# Processing Record 103 of 613 |City number: 5955902, City name: Fort Nelson
# Processing Record 104 of 613 |City number: 3622247, City name: Puerto Limón
# Processing Record 105 of 613 |City number: 2630299, City name: Hofn
# Processing Record 106 of 613 |City number: 2255304, City name: Sémbé
# Processing Record 107 of 613 |City number: 3517970, City name: Pochutla
# Processing Record 108 of 613 |City number: 1489828, City name: Teeli
# Processing Record 109 of 613 |City number: 2126199, City name: Cherskiy
# satitoa: city not found. Skipping...
# Processing Record 110 of 613 |City number: 1526038, City name: Atbasar
# Processing Record 111 of 613 |City number: 3347019, City name: Mossamedes
# Processing Record 112 of 613 |City number: 1735106, City name: George Town
# labutta: city not found. Skipping...
# tsihombe: city not found. Skipping...
# Processing Record 113 of 613 |City number: 1791779, City name: Wanning
# Processing Record 114 of 613 |City number: 3453586, City name: Piranhas
# Processing Record 211 of 613 |City number: 3394023, City name: Natal
# one hundred mile house: city not found. Skipping...
# Processing Record 212 of 613 |City number: 5295143, City name: Fortuna Foothills
# Processing Record 213 of 613 |City number: 2093846, City name: Kiunga
# Processing Record 214 of 613 |City number: 2206894, City name: Hokitika
# Processing Record 215 of 613 |City number: 3419842, City name: Sisimiut
# Processing Record 216 of 613 |City number: 775183, City name: Brzesko
# Processing Record 217 of 613 |City number: 1488903, City name: Turukhansk
# Processing Record 218 of 613 |City number: 5983720, City name: Iqaluit
# Processing Record 219 of 613 |City number: 526558, City name: Malchevskaya
# balimo: city not found. Skipping...
# safwah: city not found. Skipping...
# Processing Record 220 of 613 |City number: 924572, City name: Nsanje
# Processing Record 221 of 613 |City number: 1013076, City name: Colesberg
# Processing Record 222 of 613 |City number: 7671223, City name: Kloulklubed
# Processing Record 223 of 613 |City number: 1529376, City name: Korla
# Processing Record 224 of 613 |City number: 3421319, City name: Nuuk
# Processing Record 225 of 613 |City number: 2231881, City name: Eséka
# Processing Record 226 of 613 |City number: 3466165, City name: Cidreira
# Processing Record 227 of 613 |City number: 1214965, City name: Kabanjahe
# Processing Record 228 of 613 |City number: 2013727, City name: Vanavara
# Processing Record 229 of 613 |City number: 3545981, City name: Niquero
# Processing Record 230 of 613 |City number: 1798760, City name: Pingliang
# Processing Record 231 of 613 |City number: 2315057, City name: Kasangulu
# Processing Record 232 of 613 |City number: 1526041, City name: Atasū
# Processing Record 233 of 613 |City number: 3702577, City name: Portobelo
# Processing Record 234 of 613 |City number: 934479, City name: Grand Gaube
# Processing Record 235 of 613 |City number: 2449893, City name: Tessalit
# Processing Record 236 of 613 |City number: 1133310, City name: Mīrābād
# Processing Record 237 of 613 |City number: 3893726, City name: Constitución
# Processing Record 238 of 613 |City number: 5746545, City name: Portland
# Processing Record 239 of 613 |City number: 2015306, City name: Tiksi
# Processing Record 240 of 613 |City number: 561762, City name: Gavrilov-Yam
# Processing Record 241 of 613 |City number: 1505933, City name: Ilanskiy
# Processing Record 242 of 613 |City number: 1528796, City name: At-Bashi
# Processing Record 243 of 613 |City number: 3451234, City name: Rio Claro
# Processing Record 244 of 613 |City number: 599602, City name: Elektrėnai
# Processing Record 245 of 613 |City number: 740481, City name: Rize
# Processing Record 246 of 613 |City number: 1513491, City name: Yangi Marg`ilon
# Processing Record 247 of 613 |City number: 2022773, City name: Khandyga
# Processing Record 248 of 613 |City number: 5582371, City name: Steamboat Springs
# Processing Record 249 of 613 |City number: 3932145, City name: Pisco
# sedelnikovo: city not found. Skipping...
# Processing Record 250 of 613 |City number: 3620266, City name: Corn Island
# Processing Record 251 of 613 |City number: 964432, City name: Port Alfred
# Processing Record 252 of 613 |City number: 3404558, City name: Cabedelo
# Processing Record 253 of 613 |City number: 1079048, City name: Ambovombe
# Processing Record 254 of 613 |City number: 2171722, City name: Charters Towers
# Processing Record 255 of 613 |City number: 3372964, City name: Lagoa
# Processing Record 256 of 613 |City number: 1698289, City name: Pundaguitan
# Processing Record 257 of 613 |City number: 2450173, City name: Taoudenni
# Processing Record 258 of 613 |City number: 2270385, City name: Camacha
# Processing Record 259 of 613 |City number: 4921868, City name: Indiana
# kamenskoye: city not found. Skipping...
# Processing Record 260 of 613 |City number: 2063039, City name: Port Keats
# Processing Record 261 of 613 |City number: 1180729, City name: Dalbandin
# Processing Record 262 of 613 |City number: 1640344, City name: Kendari
# Processing Record 263 of 613 |City number: 2656708, City name: Ayr
# el badari: city not found. Skipping...
# Processing Record 264 of 613 |City number: 2181625, City name: Te Anau
# Processing Record 265 of 613 |City number: 2278158, City name: Buchanan
# Processing Record 266 of 613 |City number: 780687, City name: Berlevåg
# Processing Record 267 of 613 |City number: 4004293, City name: Ixtapa
# Processing Record 268 of 613 |City number: 2013918, City name: Ust-Maya
# Processing Record 269 of 613 |City number: 3527213, City name: Guerrero
# Processing Record 270 of 613 |City number: 3414079, City name: Olafsvik
# Processing Record 271 of 613 |City number: 2281120, City name: Tabou
# Processing Record 272 of 613 |City number: 1485997, City name: Yeniseysk
# Processing Record 273 of 613 |City number: 4147241, City name: Belle Glade
# Processing Record 274 of 613 |City number: 2065594, City name: Mount Isa
# Processing Record 275 of 613 |City number: 4342816, City name: Sulphur
# Processing Record 276 of 613 |City number: 2715656, City name: Fagersta
# Processing Record 277 of 613 |City number: 2068110, City name: Kununurra
# Processing Record 278 of 613 |City number: 2173125, City name: Burnie
# Processing Record 279 of 613 |City number: 5463237, City name: Corrales
# Processing Record 280 of 613 |City number: 3981432, City name: Todos Santos
# Processing Record 281 of 613 |City number: 1283285, City name: Jumla
# Processing Record 282 of 613 |City number: 1626703, City name: Soe
# Processing Record 283 of 613 |City number: 3445026, City name: Vila Velha
# Processing Record 284 of 613 |City number: 2123278, City name: Mil'kovo
# Processing Record 285 of 613 |City number: 2028164, City name: Deputatsky
# toulepleu: city not found. Skipping...
# Processing Record 286 of 613 |City number: 1271464, City name: Gaurela
# Processing Record 287 of 613 |City number: 2409914, City name: Bonthe
# Processing Record 288 of 613 |City number: 4513583, City name: Hamilton
# Processing Record 289 of 613 |City number: 2063036, City name: Port Lincoln
# Processing Record 290 of 613 |City number: 1264976, City name: Leh
# Processing Record 291 of 613 |City number: 478050, City name: Ust'-Kulom
# Processing Record 292 of 613 |City number: 3388847, City name: São Félix do Xingu
# Processing Record 293 of 613 |City number: 2214827, City name: Mizdah
# Processing Record 294 of 613 |City number: 2094027, City name: Kieta
# Processing Record 295 of 613 |City number: 3407762, City name: Amapá
# Processing Record 296 of 613 |City number: 3421765, City name: Nanortalik
# Processing Record 297 of 613 |City number: 6157355, City name: Stonewall
# Processing Record 298 of 613 |City number: 3155152, City name: Gravdal
# Processing Record 299 of 613 |City number: 1649150, City name: Bengkulu
# Processing Record 300 of 613 |City number: 1283334, City name: Birin
# Processing Record 301 of 613 |City number: 2276492, City name: Harper
# Processing Record 302 of 613 |City number: 3354077, City name: Opuwo
# Processing Record 303 of 613 |City number: 2417795, City name: Mandiana
# Processing Record 304 of 613 |City number: 1488920, City name: Turochak
# Processing Record 305 of 613 |City number: 2144528, City name: Warrnambool
# zolotinka: city not found. Skipping...
# Processing Record 306 of 613 |City number: 710129, City name: Derazhnya
# Processing Record 307 of 613 |City number: 1640972, City name: Katobu
# Processing Record 308 of 613 |City number: 4845585, City name: Westport
# Processing Record 309 of 613 |City number: 2015646, City name: Taldan
# Processing Record 310 of 613 |City number: 3573374, City name: The Valley
# Processing Record 311 of 613 |City number: 935214, City name: Saint-Pierre
# Processing Record 312 of 613 |City number: 1529484, City name: Kumul
# Processing Record 313 of 613 |City number: 1519385, City name: Sergeevka
# Processing Record 314 of 613 |City number: 3421719, City name: Narsaq
# Processing Record 315 of 613 |City number: 2093685, City name: Kokopo
# Processing Record 316 of 613 |City number: 5905393, City name: Bonavista
# Processing Record 317 of 613 |City number: 5919850, City name: Chapais
# Processing Record 318 of 613 |City number: 3171985, City name: Orbetello
# Processing Record 319 of 613 |City number: 609906, City name: Fort-Shevchenko
# Processing Record 320 of 613 |City number: 3393692, City name: Itarema
# Processing Record 321 of 613 |City number: 3662574, City name: Rio Branco
# Processing Record 322 of 613 |City number: 2447513, City name: Arlit
# Processing Record 323 of 613 |City number: 1850523, City name: Tateyama
# Processing Record 324 of 613 |City number: 3466980, City name: Caravelas
# Processing Record 325 of 613 |City number: 3628473, City name: San Cristobal
# Processing Record 326 of 613 |City number: 2015701, City name: Taksimo
# Processing Record 327 of 613 |City number: 3176982, City name: Finale Ligure
# Processing Record 328 of 613 |City number: 2649784, City name: Eyemouth
# Processing Record 329 of 613 |City number: 2027198, City name: Balagansk
# Processing Record 330 of 613 |City number: 1490256, City name: Talnakh
# Processing Record 331 of 613 |City number: 3418910, City name: Upernavik
# Processing Record 332 of 613 |City number: 3939761, City name: Hualmay
# Processing Record 333 of 613 |City number: 3382226, City name: Camopi
# Processing Record 334 of 613 |City number: 1806408, City name: Yangjiang
# Processing Record 335 of 613 |City number: 1792916, City name: Tianpeng
# Processing Record 336 of 613 |City number: 6096551, City name: Pangnirtung
# Processing Record 337 of 613 |City number: 1512019, City name: Aksarka
# Processing Record 338 of 613 |City number: 2172797, City name: Cairns
# Processing Record 339 of 613 |City number: 5850554, City name: Makakilo City
# Processing Record 340 of 613 |City number: 352628, City name: Maţāy
# Processing Record 341 of 613 |City number: 292968, City name: Abu Dhabi
# Processing Record 342 of 613 |City number: 3401845, City name: Conceição do Araguaia
# Processing Record 343 of 613 |City number: 2729907, City name: Longyearbyen
# barentsburg: city not found. Skipping...
# Processing Record 344 of 613 |City number: 4033356, City name: Tiarei
# Processing Record 345 of 613 |City number: 3380290, City name: Sinnamary
# Processing Record 346 of 613 |City number: 2038421, City name: Bayan
# Processing Record 347 of 613 |City number: 582447, City name: Almaznyy
# Processing Record 348 of 613 |City number: 1816028, City name: Caohai
# Processing Record 349 of 613 |City number: 3404817, City name: Breves
# Processing Record 350 of 613 |City number: 2017658, City name: Preobrazheniye
# Processing Record 351 of 613 |City number: 1040652, City name: Maputo
# Processing Record 352 of 613 |City number: 525585, City name: Molochnoye
# khonuu: city not found. Skipping...
# Processing Record 353 of 613 |City number: 232490, City name: Lukaya
# kadykchan: city not found. Skipping...
# mutsamudu: city not found. Skipping...
# Processing Record 354 of 613 |City number: 359792, City name: Aswān
# Processing Record 355 of 613 |City number: 2108502, City name: Honiara
# Processing Record 356 of 613 |City number: 1861280, City name: Itoman
# Processing Record 357 of 613 |City number: 2698767, City name: Kumla
# samalaeulu: city not found. Skipping...
# Processing Record 358 of 613 |City number: 3909234, City name: Oruro
# Processing Record 359 of 613 |City number: 4178003, City name: Weston
# Processing Record 360 of 613 |City number: 2014078, City name: Urusha
# Processing Record 361 of 613 |City number: 5134295, City name: Rome
# naftah: city not found. Skipping...
# Processing Record 362 of 613 |City number: 5229794, City name: Mitchell
# Processing Record 363 of 613 |City number: 4946620, City name: Palmer
# Processing Record 364 of 613 |City number: 3440777, City name: Rocha
# Processing Record 365 of 613 |City number: 1512205, City name: Abaza
# Processing Record 366 of 613 |City number: 3451138, City name: Rio Grande
# Processing Record 367 of 613 |City number: 918905, City name: Chinsali
# Processing Record 368 of 613 |City number: 1519938, City name: Karatau
# Processing Record 369 of 613 |City number: 3983035, City name: Sinaloa
# sentyabrskiy: city not found. Skipping...
# Processing Record 370 of 613 |City number: 4031742, City name: Egvekinot
# xadani: city not found. Skipping...
# Processing Record 371 of 613 |City number: 6319315, City name: Fonte Boa
# Processing Record 372 of 613 |City number: 1337619, City name: Ugoofaaru
# vaitupu: city not found. Skipping...
# Processing Record 373 of 613 |City number: 523392, City name: Naryan-Mar
# Processing Record 374 of 613 |City number: 1487164, City name: Veseloyarsk
# Processing Record 375 of 613 |City number: 5924351, City name: Clyde River
# Processing Record 376 of 613 |City number: 5859699, City name: College
# Processing Record 377 of 613 |City number: 718113, City name: Létavértes
# Processing Record 378 of 613 |City number: 3408386, City name: Acará
# Processing Record 379 of 613 |City number: 1223738, City name: Weligama
# Processing Record 380 of 613 |City number: 2338660, City name: Yaan
# Processing Record 381 of 613 |City number: 3430443, City name: Necochea
# Processing Record 382 of 613 |City number: 3151942, City name: Hommelvik
# Processing Record 383 of 613 |City number: 5861897, City name: Fairbanks
# Processing Record 384 of 613 |City number: 5762718, City name: Belle Fourche
# Processing Record 385 of 613 |City number: 113491, City name: Tākestān
# Processing Record 386 of 613 |City number: 3393536, City name: Olinda
# Processing Record 387 of 613 |City number: 2036892, City name: Hohhot
# Processing Record 388 of 613 |City number: 1048364, City name: Chokwé
# Processing Record 389 of 613 |City number: 2037069, City name: Hailun
# Processing Record 390 of 613 |City number: 2121909, City name: Poronaysk
# Processing Record 391 of 613 |City number: 5973108, City name: Hearst
# Processing Record 392 of 613 |City number: 1795196, City name: Tongchuanshi
# Processing Record 393 of 613 |City number: 64814, City name: Bandarbeyla
# Processing Record 394 of 613 |City number: 3407407, City name: Aquiraz
# Processing Record 395 of 613 |City number: 2030065, City name: Mandalgovi
# Processing Record 396 of 613 |City number: 1630789, City name: Pontianak
# Processing Record 397 of 613 |City number: 3453078, City name: Ponte Nova
# dzhusaly: city not found. Skipping...
# Processing Record 398 of 613 |City number: 496358, City name: Severnyy
# Processing Record 399 of 613 |City number: 2120591, City name: Tilichiki
# Processing Record 400 of 613 |City number: 3662342, City name: São Gabriel da Cachoeira
# Processing Record 401 of 613 |City number: 2156643, City name: Mount Gambier
# Processing Record 402 of 613 |City number: 1852357, City name: Shimoda
# Processing Record 403 of 613 |City number: 88533, City name: Awjilah
# Processing Record 404 of 613 |City number: 1272140, City name: Dwārka
# Processing Record 405 of 613 |City number: 1174451, City name: Keti Bandar
# Processing Record 406 of 613 |City number: 5969025, City name: Haines Junction
# Processing Record 407 of 613 |City number: 2160517, City name: Launceston
# Processing Record 408 of 613 |City number: 3374210, City name: São Filipe
# Processing Record 409 of 613 |City number: 2032614, City name: Baruun-Urt
# Processing Record 410 of 613 |City number: 3460087, City name: Jardim
# Processing Record 411 of 613 |City number: 2122783, City name: Katangli
# achisay: city not found. Skipping...
# Processing Record 412 of 613 |City number: 2446796, City name: Bilma
# Processing Record 413 of 613 |City number: 2221530, City name: Tibati
# Processing Record 414 of 613 |City number: 352733, City name: Marsá Maţrūḩ
# Processing Record 415 of 613 |City number: 2460954, City name: Araouane
# Processing Record 416 of 613 |City number: 6171633, City name: Ucluelet
# Processing Record 417 of 613 |City number: 964712, City name: Plettenberg Bay
# Processing Record 418 of 613 |City number: 2618795, City name: Klaksvík
# Processing Record 419 of 613 |City number: 2520493, City name: Calvià
# Processing Record 420 of 613 |City number: 53372, City name: Oodweyne
# Processing Record 421 of 613 |City number: 2015913, City name: Suntar
# Processing Record 422 of 613 |City number: 3456848, City name: Monte Carmelo
# Processing Record 423 of 613 |City number: 5954718, City name: Flin Flon
# Processing Record 424 of 613 |City number: 3893629, City name: Coquimbo
# Processing Record 425 of 613 |City number: 2933882, City name: Eberswalde
# Processing Record 426 of 613 |City number: 933277, City name: Mosetse
# Processing Record 427 of 613 |City number: 4574324, City name: Charleston
# Processing Record 428 of 613 |City number: 1513996, City name: Gazalkent
# Processing Record 429 of 613 |City number: 609924, City name: Emba
# Processing Record 430 of 613 |City number: 3412093, City name: Vestmannaeyjar
# Processing Record 431 of 613 |City number: 1168312, City name: Pasni
# Processing Record 432 of 613 |City number: 3402648, City name: Carutapera
# Processing Record 433 of 613 |City number: 1524302, City name: Ereymentau
# Processing Record 434 of 613 |City number: 2125693, City name: Evensk
# Processing Record 435 of 613 |City number: 653272, City name: Kemijärvi
# Processing Record 436 of 613 |City number: 5851349, City name: Nānākuli
# Processing Record 437 of 613 |City number: 380348, City name: Abū Zabad
# Processing Record 438 of 613 |City number: 3167520, City name: Santa Marinella
# Processing Record 439 of 613 |City number: 2269142, City name: Colares
# Processing Record 440 of 613 |City number: 3433715, City name: Goya
# Processing Record 441 of 613 |City number: 5666648, City name: Missoula
# blensong: city not found. Skipping...
# Processing Record 442 of 613 |City number: 1486321, City name: Yar-Sale
# Processing Record 443 of 613 |City number: 3395981, City name: Maceió
# Processing Record 444 of 613 |City number: 5321473, City name: Winslow
# lolua: city not found. Skipping...
# Processing Record 445 of 613 |City number: 3374333, City name: Praia
# Processing Record 446 of 613 |City number: 5838199, City name: Sheridan
# Processing Record 447 of 613 |City number: 2392087, City name: Porto-Novo
# Processing Record 448 of 613 |City number: 3143034, City name: Farnes
# Processing Record 449 of 613 |City number: 2134814, City name: Sola
# kasra: city not found. Skipping...
# fort saint john: city not found. Skipping...
# Processing Record 450 of 613 |City number: 197745, City name: Garissa
# Processing Record 451 of 613 |City number: 2132606, City name: Samarai
# Processing Record 452 of 613 |City number: 2310046, City name: Bata
# Processing Record 453 of 613 |City number: 3827693, City name: La Macarena
# Processing Record 454 of 613 |City number: 3836873, City name: San Miguel de Tucumán
# Processing Record 455 of 613 |City number: 2347758, City name: Bara
# Processing Record 456 of 613 |City number: 3571913, City name: Marsh Harbour
# Processing Record 457 of 613 |City number: 2699310, City name: Kristianstad
# lushunkou: city not found. Skipping...
# Processing Record 458 of 613 |City number: 6115187, City name: Quesnel
# Processing Record 459 of 613 |City number: 110690, City name: Faya
# Processing Record 460 of 613 |City number: 3389860, City name: Salgueiro
# Processing Record 461 of 613 |City number: 1631905, City name: Payakumbuh
# Processing Record 462 of 613 |City number: 371745, City name: Kutum
# Processing Record 463 of 613 |City number: 7601762, City name: Bairiki Village
# kachikau: city not found. Skipping...
# tubruq: city not found. Skipping...
# Processing Record 464 of 613 |City number: 3175096, City name: Laas
# Processing Record 465 of 613 |City number: 3391889, City name: Pitimbu
# Processing Record 466 of 613 |City number: 2161515, City name: Kiama
# Processing Record 467 of 613 |City number: 3723779, City name: Jacmel
# Processing Record 468 of 613 |City number: 3374120, City name: Vila do Maio
# Processing Record 469 of 613 |City number: 579503, City name: Balakhonovskoye
# Processing Record 470 of 613 |City number: 1842966, City name: Gijang
# Processing Record 471 of 613 |City number: 5735537, City name: La Grande
# Processing Record 472 of 613 |City number: 3354071, City name: Oranjemund
# Processing Record 473 of 613 |City number: 3838859, City name: Río Gallegos
# Processing Record 474 of 613 |City number: 2177069, City name: Ballina
# Processing Record 475 of 613 |City number: 2120769, City name: Talaya
# Processing Record 476 of 613 |City number: 3422683, City name: Kangaatsiaq
# Processing Record 477 of 613 |City number: 2026786, City name: Berezovyy
# Processing Record 478 of 613 |City number: 6162654, City name: Témiscaming
# Processing Record 479 of 613 |City number: 3557758, City name: Guane
# Processing Record 480 of 613 |City number: 2434985, City name: Bokoro
# Processing Record 481 of 613 |City number: 1686123, City name: Siocon
# Processing Record 482 of 613 |City number: 2119283, City name: Zyryanka
# Processing Record 483 of 613 |City number: 64435, City name: Berbera
# Processing Record 484 of 613 |City number: 4726521, City name: San Patricio
# Processing Record 485 of 613 |City number: 2629833, City name: Husavik
# Processing Record 486 of 613 |City number: 933815, City name: Dekar
# Processing Record 487 of 613 |City number: 1490624, City name: Surgut
# Processing Record 488 of 613 |City number: 6453316, City name: Tromsø
# Processing Record 489 of 613 |City number: 4400183, City name: Neosho
# Processing Record 490 of 613 |City number: 1215502, City name: Banda Aceh
# Processing Record 491 of 613 |City number: 6113406, City name: Prince Rupert
# Processing Record 492 of 613 |City number: 3943789, City name: Chincha Alta
# malwan: city not found. Skipping...
# Processing Record 493 of 613 |City number: 4021858, City name: Guerrero Negro
# Processing Record 494 of 613 |City number: 2194098, City name: Ahipara
# Processing Record 495 of 613 |City number: 1899102, City name: Nagato
# Processing Record 496 of 613 |City number: 961226, City name: Ritchie
# Processing Record 497 of 613 |City number: 2122104, City name: Petropavlovsk-Kamchatskiy
# Processing Record 498 of 613 |City number: 2264923, City name: Peniche
# Processing Record 499 of 613 |City number: 1789289, City name: Dayong
# Processing Record 500 of 613 |City number: 2444995, City name: Filingué
# Processing Record 501 of 613 |City number: 5354943, City name: Half Moon Bay
# Processing Record 502 of 613 |City number: 2088122, City name: Port Moresby
# Processing Record 503 of 613 |City number: 3433663, City name: Gualeguay
# Processing Record 504 of 613 |City number: 1639304, City name: Kualakapuas
# Processing Record 505 of 613 |City number: 2123979, City name: Kuril'sk
# Processing Record 506 of 613 |City number: 1028434, City name: Quelimane
# Processing Record 507 of 613 |City number: 3405616, City name: Boa Viagem
# Processing Record 508 of 613 |City number: 5392171, City name: San Jose
# Processing Record 509 of 613 |City number: 1220826, City name: Farkhor
# Processing Record 510 of 613 |City number: 3464008, City name: Esmeraldas
# Processing Record 511 of 613 |City number: 4171522, City name: St. Pete Beach
# Processing Record 512 of 613 |City number: 2294915, City name: Takoradze
# Processing Record 513 of 613 |City number: 686090, City name: Asău
# Processing Record 514 of 613 |City number: 6164499, City name: The Pas
# Processing Record 515 of 613 |City number: 1326105, City name: Falam
# Processing Record 516 of 613 |City number: 1855342, City name: Nishihara
# Processing Record 517 of 613 |City number: 1519691, City name: Sarkand
# Processing Record 518 of 613 |City number: 1160571, City name: Khāsh
# Processing Record 519 of 613 |City number: 1516048, City name: Khovd
# Processing Record 520 of 613 |City number: 172515, City name: Abu Samrah
# Processing Record 521 of 613 |City number: 3382867, City name: Totness
# Processing Record 522 of 613 |City number: 3533462, City name: Acapulco de Juárez
# Processing Record 523 of 613 |City number: 2665171, City name: Vänersborg
# Processing Record 524 of 613 |City number: 1510689, City name: Baykit
# samusu: city not found. Skipping...
# Processing Record 525 of 613 |City number: 2129211, City name: Misawa
# Processing Record 526 of 613 |City number: 1636806, City name: Majene
# Processing Record 527 of 613 |City number: 1638368, City name: Kaili
# Processing Record 528 of 613 |City number: 3902377, City name: La Santisima Trinidad
# Processing Record 529 of 613 |City number: 2191562, City name: Dunedin
# Processing Record 530 of 613 |City number: 105298, City name: Jizan
# tawkar: city not found. Skipping...
# Processing Record 531 of 613 |City number: 1254046, City name: Tura
# Processing Record 532 of 613 |City number: 3577430, City name: Road Town
# Processing Record 533 of 613 |City number: 3021717, City name: Darnétal
# Processing Record 534 of 613 |City number: 6255012, City name: Flinders
# Processing Record 535 of 613 |City number: 738927, City name: Tekirdağ
# Processing Record 536 of 613 |City number: 135423, City name: Shahrud
# Processing Record 537 of 613 |City number: 1257551, City name: Samāstipur
# Processing Record 538 of 613 |City number: 1260880, City name: Pahlgām
# Processing Record 539 of 613 |City number: 1635815, City name: Maumere
# Processing Record 540 of 613 |City number: 2654970, City name: Brae
# Processing Record 541 of 613 |City number: 5983607, City name: Inuvik
# Processing Record 542 of 613 |City number: 6050066, City name: La Ronge
# Processing Record 543 of 613 |City number: 3868707, City name: Valdivia
# Processing Record 544 of 613 |City number: 2150163, City name: Sawtell
# Processing Record 545 of 613 |City number: 472278, City name: Vol'sk
# Processing Record 546 of 613 |City number: 342641, City name: Batī
# bolshegrivskoye: city not found. Skipping...
# Processing Record 547 of 613 |City number: 528278, City name: Mayna
# Processing Record 548 of 613 |City number: 569318, City name: Cheremshan
# Processing Record 549 of 613 |City number: 1634614, City name: Nabire
# Processing Record 550 of 613 |City number: 5892532, City name: Banff
# Processing Record 551 of 613 |City number: 3653967, City name: Muisne
# Processing Record 552 of 613 |City number: 866062, City name: Iskateley
# Processing Record 553 of 613 |City number: 510911, City name: Pervomayskiy
# Processing Record 554 of 613 |City number: 4172445, City name: Seminole
# Processing Record 555 of 613 |City number: 515246, City name: Onega
# Processing Record 556 of 613 |City number: 1632694, City name: Pangkalanbuun
# Processing Record 557 of 613 |City number: 2120048, City name: Ust-Nera
# Processing Record 558 of 613 |City number: 2398269, City name: Moanda
# Processing Record 559 of 613 |City number: 1783940, City name: Zhuji
# Processing Record 560 of 613 |City number: 3137469, City name: Sørland
# Processing Record 561 of 613 |City number: 4120323, City name: Magnolia
# Processing Record 562 of 613 |City number: 1849782, City name: Tsubata
# Processing Record 563 of 613 |City number: 3347939, City name: Lobito
# Processing Record 564 of 613 |City number: 1733953, City name: Lahad Datu
# Processing Record 565 of 613 |City number: 2059470, City name: Victor Harbor
# Processing Record 566 of 613 |City number: 2093691, City name: Kokoda
# Processing Record 567 of 613 |City number: 3180208, City name: Casale Monferrato
# Processing Record 568 of 613 |City number: 5344157, City name: Dublin

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export the city data into a .csv.
meteorology_cities.to_csv("output_data/meteorology_of_cities.csv", index=False, header=True)
# Display the DataFrame
for date_ in meteorology_cities['Date']:
    meteorology_cities['Date'] = datetime.fromtimestamp(date_).strftime('%m/%d/%Y')
meteorology_cities
# Out:
#                   City      Lat       Lng   Temp  Humidity  Cloudiness  \
# 0            Nantucket  41.2835  -70.0995  40.53        56           1
# 1                 Jalu  29.0331   21.5482  66.58        30          55
# 2         Kruisfontein -34.0033   24.7314  72.00        80           0
# 3          Yellowknife  62.4560 -114.3525 -46.28        65           1
# 4              Rikitea -23.1203 -134.9692  77.47        75         100
# ..                 ...      ...       ...    ...       ...         ...
# 563         Lahad Datu   5.0268  118.3270  75.43        93         100
# 564      Victor Harbor -35.5667  138.6167  58.39        98         100
# 565             Kokoda  -8.8785  147.7407  75.88        67         100
# 566  Casale Monferrato  45.1334    8.4571  47.01        84         100
# 567             Dublin  37.7021 -121.9358  51.60        62           1
#
#      Wind Speed Country        Date
# 0         21.85      US  02/06/2021
# 1          8.43      LY  02/06/2021
# 2          1.01      ZA  02/06/2021
# 3          4.34      CA  02/06/2021
# 4         13.15      PF  02/06/2021
# ..          ...     ...         ...
# 563        5.21      MY  02/06/2021
# 564        3.00      AU  02/06/2021
# 565        1.66      PG  02/06/2021
# 566        3.71      IT  02/06/2021
# 567        3.44      US  02/06/2021
#
# [568 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
Weather_cities_statistic = meteorology_cities.describe(percentiles=None, include=None, exclude=None, datetime_is_numeric=False)
Weather_cities_statistic
# Out:
#               Lat         Lng        Temp    Humidity  Cloudiness  Wind Speed
# count  568.000000  568.000000  568.000000  568.000000  568.000000  568.000000
# mean    20.213835   20.994847   49.570194   71.933099   53.695423    8.566937
# std     33.740884   91.253384   33.978839   20.995400   39.031311    6.056333
# min    -54.800000 -179.166700  -46.280000    1.000000    0.000000    0.290000
# 25%     -6.728800  -57.673350   27.825000   62.000000   12.000000    4.000000
# 50%     25.142000   24.699050   59.000000   78.000000   69.500000    6.910000
# 75%     49.229825  102.638600   77.455000   87.000000   90.000000   11.925000
# max     78.218600  179.316700  101.050000  100.000000  100.000000   42.570000

# %%
#  Get the indices of cities that have humidity over 100%
#city_Hum100 =  meteorology_cities.index[meteorology_cities['Humidity'] > 100 ].tolist()
city_Hum100 = meteorology_cities[(meteorology_cities['Humidity'] > 100)]
if len(city_Hum100) == 0:
    clean_city_data = meteorology_cities.copy()
    print(f"Skip this step if there are no cities that have humidity > 100%.")
    print(city_Hum100.index)
else:
    clean_city_data = meteorology_cities[(meteorology_cities['Humidity'] < 100)]
    clean_city_data_statistic = clean_city_data.describe(percentiles=None, include=None, exclude=None, datetime_is_numeric=False)
    print(f"Indices of cities that have humidity over 100%.: {city_Hum100.index}")
    print(f"=========================================================================")
    print(f"{clean_city_data_statistic}")
# Out:
# Skip this step if there are no cities that have humidity > 100%.
# Int64Index([], dtype='int64')

# %%
#which we call "clean_city_data"
clean_city_data
# Out:
#                   City      Lat       Lng   Temp  Humidity  Cloudiness  \
# 0            Nantucket  41.2835  -70.0995  40.53        56           1
# 1                 Jalu  29.0331   21.5482  66.58        30          55
# 2         Kruisfontein -34.0033   24.7314  72.00        80           0
# 3          Yellowknife  62.4560 -114.3525 -46.28        65           1
# 4              Rikitea -23.1203 -134.9692  77.47        75         100
# ..                 ...      ...       ...    ...       ...         ...
# 563         Lahad Datu   5.0268  118.3270  75.43        93         100
# 564      Victor Harbor -35.5667  138.6167  58.39        98         100
# 565             Kokoda  -8.8785  147.7407  75.88        67         100
# 566  Casale Monferrato  45.1334    8.4571  47.01        84         100
# 567             Dublin  37.7021 -121.9358  51.60        62           1
#
#      Wind Speed Country        Date
# 0         21.85      US  02/06/2021
# 1          8.43      LY  02/06/2021
# 2          1.01      ZA  02/06/2021
# 3          4.34      CA  02/06/2021
# 4         13.15      PF  02/06/2021
# ..          ...     ...         ...
# 563        5.21      MY  02/06/2021
# 564        3.00      AU  02/06/2021
# 565        1.66      PG  02/06/2021
# 566        3.71      IT  02/06/2021
# 567        3.44      US  02/06/2021
#
# [568 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
date = clean_city_data['Date'].max()
plt.style.use('seaborn')
x = clean_city_data['Lat']
y = clean_city_data['Temp']
ratio = clean_city_data['Temp'] #[1, 0.53, 2, 0.76, 0.5, 2.125, 0.56, 1.28, 1.09, 1.02]
plt.scatter(x, y, s=100, c=ratio, cmap="summer", edgecolor="#FFD500", linewidth=1, alpha=0.75)
cbar = plt.colorbar()
cbar.set_label('Latitud vs max Temperature')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
date = clean_city_data['Date'].max()
plt.style.use('seaborn')
x = clean_city_data['Lat']
y = clean_city_data['Humidity']
plt.scatter(x, y, s=100, c=ratio, cmap="RdYlBu_r", edgecolor="#FFD500", linewidth=1, alpha=0.75)
plt.title(f"Latitude of cities vs Humidity | {date}", fontsize = "12")
plt.xlabel(f"Latitude", fontsize="14")
plt.ylabel(f"Humidity", fontsize="14")
cbar= plt.colorbar()
cbar.set_label('Latitud vs Humidity')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
date = clean_city_data['Date'].max()
plt.style.use('seaborn')
x = clean_city_data['Lat']
y = clean_city_data['Cloudiness']
s=plt.scatter(x,y, s=100, c='#000050', edgecolor='black', linewidth=1, alpha=0.75);
plt.title(f"Latitude of cities vs Cloudiness | {date}", fontsize = "12")
plt.xlabel(f"Latitude", fontsize="14")
plt.ylabel(f"Cloudiness", fontsize="14")
cbar= plt.colorbar(s.colorbar)
cbar.set_label('Latitud vs Cloudiness')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
date = clean_city_data['Date'].max()
plt.style.use('seaborn')
x = clean_city_data['Lat']
y = clean_city_data['Wind Speed']
plt.scatter(x,y, s=100, c='#000050', edgecolor='black', linewidth=1, alpha=0.75);
plt.title(f"Latitude of cities vs Wind Speed (miles/hour) | {date}", fontsize = "12")
plt.xlabel(f"Latitude", fontsize="14")
plt.ylabel(f"Wind Speed (miles/hour)", fontsize="14")
cbar.set_label('Latitud vs Wind Speed (miles/hour)')

# %% [markdown]
# ## Linear Regression

# %%
#Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
print(f"the intercept :{round(intercept,2)}");
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Lat linear regression model :{line_eq}");
#plt.scatter(X,Y, s=100, c="#000023", alpha=0.9, linewidths=1, edgecolors="black", sizes=sizes, cmap="viridis")
#plt.plot(x,regress_values,"r-");
# Out:
# the intercept :8.18
# Lat linear regression model :y = 0.02x + 8.18

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Northern Hemisphere = Latitude between 0 ° and 90 °: Northern Hemisphere
Northern_city_data = meteorology_cities[(meteorology_cities['Lat'] > 0)]
# Southern Hemisphere = Latitude between 0 ° and -90 °: Southern Hemisphere
Southern_city_data = meteorology_cities[(meteorology_cities['Lat'] < 0)]
date = Northern_city_data['Date'].max()
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_north=Northern_city_data['Lat']
y_north=Northern_city_data['Temp']
x_Sout=Southern_city_data['Lat']
y_Sout=Southern_city_data['Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_north, y_north)
#print(f"the intercept :{round(intercept,2)}");
regress_values = x_north * slope + intercept
line_north = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = round(rvalue,2)
plt.style.use('seaborn')
plt.scatter(x_north,y_north, s=100, c='#000050', edgecolor='black', linewidth=1, alpha=0.75);
plt.plot(x_north,regress_values,"r-")
#plt.annotate(line_north,(20,30),fontsize=14, color="red")
plt.title("Latitude of Cities vs. Temperature | {date}", fontsize = "12")
plt.xlabel("Latitude", size=14)
plt.ylabel("Max Temperature (F)", size=14)
plt.tight_layout()
cbar= plt.colorbar()
cbar.set_label('Latitud vs Wind Speed (miles/hour)')





plt.show();


#print(f"Lat linear regression model :{line_north}");
#plt.style.use('seaborn')
#plt.scatter(x,y, s=100, c='blue', edgecolor='black', linewidth=1, alpha=0.75)
#plt.plot(x_north,regress_values,"r-")
#plt.title(f"Latitude of Cities vs. Temperature | {date}", fontsize = "12")
#plt.xlabel(f"Latitude", fontsize="14")
#plt.ylabel(f"Max Temperature (F)", fontsize="14")
#cbar= plt.colorbar()
#cbar.set_label('Latitud vs max Temperature')

#plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
